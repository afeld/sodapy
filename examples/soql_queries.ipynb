# %% [markdown]
# # Example 02: SoQL Queries
#
# Constructing custom queries to conserve bandwith and computational resources

# %% [markdown]
# ## Setup

# %%
import os
# Note: we don't need Pandas
# Filters allow you to accomplish many basic operations automatically

from sodapy import Sodapy

# %% [markdown]
# ## Find Some Data
#
# As in the first example, I'm using the [NYC campaign contribution dataset](https://data.cityofnewyork.us/City-Government/Campaign-Contributions/rjkp-yttg/about_data).

# %%
socrata_domain = "data.cityofnewyork.us"
socrata_dataset_identifier = "rjkp-yttg"

# If you choose to use a token, run the following command on the terminal (or add it to your .bashrc)
# $ export SODAPY_APPTOKEN=<token>
socrata_token = os.environ.get("SODAPY_APPTOKEN")

# %%
client = Sodapy(socrata_domain, socrata_token)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %% [markdown]
# ## Use Metadata to Plan Your Query
#
# You've probably looked through the column names and descriptions in the web UI,
# but it can be nice to have them right in your workspace as well.

# %%
metadata = client.get_metadata(socrata_dataset_identifier)
metadata
# Out:
# {'resource': {'name': 'Campaign Contributions',
#   'id': 'rjkp-yttg',
#   'resource_name': None,
#   'parent_fxf': [],
#   'description': 'Contributions to election campaigns.',
#   'attribution': 'Campaign Finance Board (CFB)',
#   'attribution_link': None,
#   'contact_email': None,
#   'type': 'dataset',
#   'updatedAt': '2025-02-04T22:38:26.000Z',
#   'createdAt': '2021-02-16T00:52:16.000Z',
#   'metadata_updated_at': '2025-02-04T22:38:26.000Z',
#   'data_updated_at': '2025-02-04T22:06:26.000Z',
#   'page_views': {'page_views_last_week': 12,
#    'page_views_last_month': 57,
#    'page_views_total': 973,
#    'page_views_last_week_log': 3.700439718141092,
#    'page_views_last_month_log': 5.857980995127572,
#    'page_views_total_log': 9.927777962082342},
#   'columns_name': ['CITY',
#    'PURPOSECD',
#    'INTEMPST',
#    'INT_C_CODE',
#    'INTEMPCITY',
#    'INTEMPSTNM',
#    'INTEMPNAME',
#    'RECIPID',
#    'CANCLASS',
#    'CANDFIRST',
#    'COMMITTEE',
#    'FILING',
#    'INTCITY',
#    'REFNO',
#    'INTSTRNM',
#    'DATE',
#    'REFUNDDATE',
#    'INTSTRNO',
#    'INTERMNAME',
#    'INTERMNO',
#    'PAY_METHOD',
#    'MATCHAMNT',
#    'NAME',
#    'C_CODE',
#    'STRNO',
#    'STRNAME',
#    'APARTMENT',
#    'AMNT',
#    'BOROUGHCD',
#    'EMPSTATE',
#    'EMPCITY',
#    'STATE',
#    'INTOCCUPA',
#    'EMPNAME',
#    'EMPSTRNO',
#    'EMPSTRNAME',
#    'INTZIP',
#    'INTST',
#    'SEQUENCENO',
#    'OCCUPATION',
#    'PREVAMNT',
#    'ADJTYPECD',
#    'ELECTION',
#    'EXEMPTCD',
#    'INTAPTNO',
#    'INTEMPSTNO',
#    'PAGENO',
#    'RECIPNAME',
#    'SCHEDULE',
#    'ZIP',
#    'SEG_IND',
#    'RR_IND',
#    'CANDMI',
#    'OFFICECD'],
#   'columns_field_name': ['city',
#    'purposecd',
#    'intempst',
#    'int_c_code',
#    'intempcity',
#    'intempstnm',
#    'intempname',
#    'recipid',
#    'canclass',
#    'candfirst',
#    'committee',
#    'filing',
#    'intcity',
#    'refno',
#    'intstrnm',
#    'date',
#    'refunddate',
#    'intstrno',
#    'intermname',
#    'intermno',
#    'pay_method',
#    'matchamnt',
#    'name',
#    'c_code',
#    'strno',
#    'strname',
#    'apartment',
#    'amnt',
#    'boroughcd',
#    'empstate',
#    'empcity',
#    'state',
#    'intoccupa',
#    'empname',
#    'empstrno',
#    'empstrname',
#    'intzip',
#    'intst',
#    'sequenceno',
#    'occupation',
#    'prevamnt',
#    'adjtypecd',
#    'election',
#    'exemptcd',
#    'intaptno',
#    'intempstno',
#    'pageno',
#    'recipname',
#    'schedule',
#    'zip',
#    'seg_ind',
#    'rr_ind',
#    'candmi',
#    'officecd'],
#   'columns_datatype': ['Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Calendar date',
#    'Calendar date',
#    'Text',
#    'Text',
#    'Number',
#    'Number',
#    'Number',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Number',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Number',
#    'Number',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text'],
#   'columns_description': ["Contributor's City, Schedule N - Vendor's City",
#    'Purpose Code.  ADVAN=Advance Repayment; CMAIL=Campaign Mailings; CMISC=Campaign Miscellaneous; CNTRB=Political Contributions; COMPL=Compliance Cost; CONSL=Campaign Consultants; CONSV=Constituent Services; FUNDR=Fundraising; INTER=Interest Expenses; LITER=Campaign Literature; NQUAL=Non Qualified Expenditures; OFFCE=Office Expenses; OTHER=Other; PETIT=Petition Expenses; POLLS=Polling Costs; POSTA=Postage Expenses; PRINT=Printing Expenses; PROFL=Professional Services; RADIO=Radio Ads; RENTO=Office Rent; TVADS=Television Ads; UNKN=Unknown; VOTER=Voter Registration; WAGES=Campaign Workers Salaries.',
#    "Intermediary's Employer State",
#    "Intermediary's Name Code",
#    "Intermediary's Employer City ",
#    "Intermediary's Employer Street Name",
#    "Intermediary's Employer Name",
#    'Candidate ID',
#    'Campaign Finance Program Classification. Participant, Non-Participant, Limited Participant, Undetermined',
#    "Candidate's first name (2001-2005)",
#    'Committee ID',
#    'Disclosure Statement Filing Period',
#    "Intermediary's City",
#    'Transaction Reference Number',
#    "Intermediary's Street Name",
#    'Date Received',
#    'Date of Refund/Loan forgiven',
#    "Intermediary's Street Number",
#    "Intermediary's Name (if any)  ",
#    'Intermediary Number',
#    'Method of Payment. 0=Unknown; 1=Cash; 2=Check; 3=Other; 4=Credit Card; 5=Money Order',
#    'Matchable Amount of Contribution',
#    "Contributor's Name",
#    "Contributor Type.CAN=Candidate; CORP=Corporation; EMPO=Labor Union; FAM=Candidate's Family; IND=Individual; LLC=Limited Liability Company; OTHR=Other; PART=Partnership; PCOMC=Candidate Committee; PCOMP=Political Action Committee; PCOMZ=Party Committee; SPO=Candidate's Spouse; UNKN=Unknown",
#    "Contributor's Street Number",
#    "Contributor's Street Name",
#    "Contributor's Apartment Number",
#    'Amount',
#    "Contributor's Borough Code. K=Brooklyn; M=Manhattan; Q=Queens; S=Staten Island; X=Bronx; Z=Outside New York City",
#    "Contributor's Employer's State",
#    "Contributor's Employer's City",
#    "Contributor's State, Schedule N - Vendor's State",
#    "Intermediary's Occupation",
#    "Contributor's Employer",
#    "Contributor's Employer's Street Number",
#    "Contributor's Employer's Street Name",
#    "Intermediary's Zip Code",
#    "Intermediary's State",
#    'Sequence Number on page of schedule on which information was reported',
#    "Contributor's Occupation",
#    'Total of Previous Contributions',
#    'Schedule M/Adjustment Type Code. 0=Unknown; 1=Returned Check 2=Refund; 5=Other',
#    'Election Cycle',
#    'Exempt Code. C=Compliance Costs; E=Previous Election Costs; P=Petition Challenges; S=Constituent Services; U=Unknown; Blank = Not Exempt',
#    "Intermediary's Apartment Number",
#    "Intermediary's Employer Street Number ",
#    'Page Number of schedule on which information was reported',
#    "Candidate's Last name (2001-2005); Candidate's full name (from 2007)",
#    'Schedule. ABC=Monetary Contributions; D=In-Kind Contributions; G=Transfers In; K=Loans/Liabilities Forgiven; M=Receipt Adjustments; N=Outstanding Liabilities',
#    "Contributor's Zip Code",
#    'Segregated Indicator',
#    'Runoff/Rerun Indicator',
#    "Candidate's middle initial (2001-2005)",
#    'Office Sought. 1=Mayor; 2=Public Advocate; 3=Comptroller; 4=Borough President; 5=City Council; 6=Undeclared'],
#   'columns_format': [{},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {'view': 'date'},
#    {'view': 'date'},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {},
#    {}],
#   'download_count': 1229,
#   'provenance': 'official',
#   'lens_view_type': 'tabular',
#   'lens_display_type': 'table',
#   'locked': False,
#   'blob_mime_type': None,
#   'hide_from_data_json': False,
#   'publication_date': '2025-02-04T22:38:26.000Z'},
#  'classification': {'categories': [],
#   'tags': [],
#   'domain_category': 'City Government',
#   'domain_tags': ['contribution',
#    'contributor',
#    'donation',
#    'donor',
#    'giving',
#    'in-kind',
#    'intermediary',
#    'intermediate',
#    'refund'],
#   'domain_metadata': [{'key': 'Update_Automation', 'value': 'No'},
#    {'key': 'Update_Date-Made-Public', 'value': '3/8/2021'},
#    {'key': 'Update_Update-Frequency', 'value': 'As needed'},
#    {'key': 'Dataset-Information_Agency',
#     'value': 'Campaign Finance Board (CFB)'}]},
#  'metadata': {'domain': 'data.cityofnewyork.us'},
#  'permalink': 'https://data.cityofnewyork.us/d/rjkp-yttg',
#  'link': 'https://data.cityofnewyork.us/City-Government/Campaign-Contributions/rjkp-yttg',
#  'owner': {'id': '5fuc-pqz2',
#   'user_type': 'interactive',
#   'display_name': 'NYC OpenData'},
#  'creator': {'id': '5fuc-pqz2',
#   'user_type': 'interactive',
#   'display_name': 'NYC OpenData'}}

# %%
metadata["resource"]["columns_name"]
# Out:
# ['CITY',
#  'PURPOSECD',
#  'INTEMPST',
#  'INT_C_CODE',
#  'INTEMPCITY',
#  'INTEMPSTNM',
#  'INTEMPNAME',
#  'RECIPID',
#  'CANCLASS',
#  'CANDFIRST',
#  'COMMITTEE',
#  'FILING',
#  'INTCITY',
#  'REFNO',
#  'INTSTRNM',
#  'DATE',
#  'REFUNDDATE',
#  'INTSTRNO',
#  'INTERMNAME',
#  'INTERMNO',
#  'PAY_METHOD',
#  'MATCHAMNT',
#  'NAME',
#  'C_CODE',
#  'STRNO',
#  'STRNAME',
#  'APARTMENT',
#  'AMNT',
#  'BOROUGHCD',
#  'EMPSTATE',
#  'EMPCITY',
#  'STATE',
#  'INTOCCUPA',
#  'EMPNAME',
#  'EMPSTRNO',
#  'EMPSTRNAME',
#  'INTZIP',
#  'INTST',
#  'SEQUENCENO',
#  'OCCUPATION',
#  'PREVAMNT',
#  'ADJTYPECD',
#  'ELECTION',
#  'EXEMPTCD',
#  'INTAPTNO',
#  'INTEMPSTNO',
#  'PAGENO',
#  'RECIPNAME',
#  'SCHEDULE',
#  'ZIP',
#  'SEG_IND',
#  'RR_IND',
#  'CANDMI',
#  'OFFICECD']

# %% [markdown]
# ## Efficiently Query for Data

# %% [markdown]
# ### Restrict rows to above-average donations
#
# Using [SoQL's `avg()` function](https://dev.socrata.com/docs/functions/avg).

# %%
avg_result = client.get(socrata_dataset_identifier, select="avg(amnt)")
avg_result
# Out:
# [{'avg_amnt': '454.8782932298324902'}]

# %% [markdown]
# Use the [`where`](https://dev.socrata.com/docs/queries/where) argument to filter the data before downloading it. How many campaign contributions have there been in the past year that are more than double the average?

# %%
from datetime import datetime

avg = float(avg_result[0]["avg_amnt"])
current_year = datetime.now().year

results = client.get(
    socrata_dataset_identifier,
    where=f"amnt >= ({avg} * 2) and date_extract_y(date) == {current_year}",
)
len(results)
# Out:
# 611

# %% [markdown]
# ### Perform basic operations
#
# You can further simplify the download by specifying just the columns you want. It can also be valuable to have results in order, so that you can quickly grab the largest or smallest. You can even accomplish some basic analytics operations like finding [sums](https://dev.socrata.com/docs/functions/sum.html).
#
# If you're planning on doing further processing, note that the numeric outputs are strings by default.

# %%
results = client.get(
    socrata_dataset_identifier,
    select="sum(amnt), recipname",
    group="recipname",
    order="sum(amnt) DESC",
)
results
# Out:
# [{'sum_amnt': '108375000', 'recipname': 'Bloomberg, Michael R'},
#  {'sum_amnt': '84155868', 'recipname': 'Bloomberg'},
#  {'sum_amnt': '19082335.99', 'recipname': 'de Blasio, Bill'},
#  {'sum_amnt': '14288722.48', 'recipname': 'Adams, Eric L'},
#  {'sum_amnt': '11232542', 'recipname': 'Green'},
#  {'sum_amnt': '11083662.08', 'recipname': 'Catsimatidis, John A'},
#  {'sum_amnt': '10715128.70', 'recipname': 'Stringer, Scott M'},
#  {'sum_amnt': '10709864', 'recipname': 'Ferrer'},
#  {'sum_amnt': '10694368.19', 'recipname': 'Spitzer, Eliot L'},
#  {'sum_amnt': '10041871.86', 'recipname': 'McGuire, Raymond J'},
#  {'sum_amnt': '9356429.63', 'recipname': 'Thompson, Jr., William C'},
#  {'sum_amnt': '8119591.55', 'recipname': 'Quinn, Christine C'},
#  {'sum_amnt': '7181923', 'recipname': 'Hevesi'},
#  {'sum_amnt': '7111741.72', 'recipname': 'Liu, John C'},
#  {'sum_amnt': '6977004.20', 'recipname': 'New Start NYC'},
#  {'sum_amnt': '6960000.00', 'recipname': 'Jobs for New York, Inc.'},
#  {'sum_amnt': '6920000', 'recipname': 'Strong Leadership NYC Inc'},
#  {'sum_amnt': '6870000', 'recipname': 'New York for Ray'},
#  {'sum_amnt': '5711506', 'recipname': 'Thompson, Jr.'},
#  {'sum_amnt': '5700000', 'recipname': 'NY4KIDS Inc.'},
#  {'sum_amnt': '5616410.63', 'recipname': 'Weiner, Anthony D'},
#  {'sum_amnt': '5439787', 'recipname': 'Miller'},
#  {'sum_amnt': '4744405', 'recipname': 'Vallone'},
#  {'sum_amnt': '4068070.53', 'recipname': 'Yang, Andrew'},
#  {'sum_amnt': '3950250', 'recipname': 'New York Jobs Now Committee'},
#  {'sum_amnt': '3857240.00', 'recipname': 'The Coalition to Restore New York'},
#  {'sum_amnt': '3640593.40', 'recipname': 'Comeback PAC'},
#  {'sum_amnt': '3525000', 'recipname': 'United for the Future'},
#  {'sum_amnt': '3493184.21', 'recipname': 'Lhota, Joseph J'},
#  {'sum_amnt': '3470025.96', 'recipname': 'Katz, Melinda R'},
#  {'sum_amnt': '3443097.17', 'recipname': 'Diaz Jr., Ruben'},
#  {'sum_amnt': '3373416', 'recipname': 'Gotbaum'},
#  {'sum_amnt': '3337000',
#   'recipname': 'Hotel Workers for Stronger Communities'},
#  {'sum_amnt': '3030408.70', 'recipname': 'Massey, Jr., Paul J'},
#  {'sum_amnt': '2855301.37', 'recipname': 'Donovan, Shaun'},
#  {'sum_amnt': '2811373', 'recipname': 'Weiner'},
#  {'sum_amnt': '2675171.54', 'recipname': 'Lander, Brad'},
#  {'sum_amnt': '2532100.00', 'recipname': 'Common Sense NYC, Inc.'},
#  {'sum_amnt': '2507899.12', 'recipname': 'Weprin, David I'},
#  {'sum_amnt': '2507709.85', 'recipname': 'Yassky, David'},
#  {'sum_amnt': '2477901.11', 'recipname': 'Carrion, Jr., Adolfo'},
#  {'sum_amnt': '2427174', 'recipname': 'Fields'},
#  {'sum_amnt': '2242176', 'recipname': 'Markowitz'},
#  {'sum_amnt': '2208189.54', 'recipname': 'Wiley, Maya D'},
#  {'sum_amnt': '2162557', 'recipname': 'Stringer'},
#  {'sum_amnt': '2152252.20', 'recipname': 'Garcia, Kathryn A'},
#  {'sum_amnt': '2104638.55', 'recipname': 'Gioia, Eric'},
#  {'sum_amnt': '2086602.45', 'recipname': 'Squadron, Daniel L'},
#  {'sum_amnt': '2017871.00', 'recipname': 'James, Letitia'},
#  {'sum_amnt': '1800352', 'recipname': 'Berman'},
#  {'sum_amnt': '1794831.37', 'recipname': 'Menin, Julie'},
#  {'sum_amnt': '1791033.12', 'recipname': 'Growing Economic Opportunities'},
#  {'sum_amnt': '1740745.97', 'recipname': 'Garodnick, Daniel R'},
#  {'sum_amnt': '1593479', 'recipname': 'Carrion, Jr.'},
#  {'sum_amnt': '1538700', 'recipname': '1199 for Maya'},
#  {'sum_amnt': '1520000',
#   'recipname': 'HOTEL WORKERS FOR A STRONGER MIDDLE CLASS'},
#  {'sum_amnt': '1502756.44', 'recipname': 'Saujani, Reshma M'},
#  {'sum_amnt': '1499230', 'recipname': 'Laborers Building a Better New York'},
#  {'sum_amnt': '1477923.54', 'recipname': 'Johnson, Corey D'},
#  {'sum_amnt': '1403319.50', 'recipname': 'Gjonaj, Mark'},
#  {'sum_amnt': '1401108.24', 'recipname': 'Katz, Melinda'},
#  {'sum_amnt': '1332427', 'recipname': 'Moskowitz'},
#  {'sum_amnt': '1326736.0', 'recipname': 'Markowitz, Marty'},
#  {'sum_amnt': '1288500', 'recipname': 'Empire State 32BJ SEIU PAC'},
#  {'sum_amnt': '1271928.26', 'recipname': 'Levine, Mark'},
#  {'sum_amnt': '1262085.77', 'recipname': 'Sliwa, Curtis'},
#  {'sum_amnt': '1261000', 'recipname': 'New York Progress'},
#  {'sum_amnt': '1233808.37', 'recipname': 'Vallone, Jr., Peter F'},
#  {'sum_amnt': '1189916.07', 'recipname': 'Lappin, Jessica S'},
#  {'sum_amnt': '1188592.01', 'recipname': 'Malliotakis, Nicole'},
#  {'sum_amnt': '1177878.13', 'recipname': 'Mark-Viverito, Melissa'},
#  {'sum_amnt': '1158000', 'recipname': 'Labor Strong 2023'},
#  {'sum_amnt': '1157000', 'recipname': 'NYCN4S'},
#  {'sum_amnt': '1133339', 'recipname': 'Koo, Peter A'},
#  {'sum_amnt': '1100009', 'recipname': 'Katz'},
#  {'sum_amnt': '1096164.17', 'recipname': 'Crowley, Elizabeth S'},
#  {'sum_amnt': '1050000', 'recipname': 'Labor Strong 2021'},
#  {'sum_amnt': '1040809.13',
#   'recipname': 'POLICE BENEVOLENT ASSOCIATION INDEPENDENT EXPENDIT'},
#  {'sum_amnt': '1031528.28', 'recipname': 'Dietl, Richard A'},
#  {'sum_amnt': '1024444', 'recipname': 'Molinaro'},
#  {'sum_amnt': '1022174.20', 'recipname': 'Iscol, Zachary'},
#  {'sum_amnt': '1016809', 'recipname': 'Fisher'},
#  {'sum_amnt': '998147.6', 'recipname': 'WFP National PAC - NYS IE Committee'},
#  {'sum_amnt': '994057', 'recipname': 'Weprin'},
#  {'sum_amnt': '977232', 'recipname': 'Greenfield, David G'},
#  {'sum_amnt': '972018.62', 'recipname': 'Williams, Jumaane D'},
#  {'sum_amnt': '963897', 'recipname': 'Gioia'},
#  {'sum_amnt': '932182', 'recipname': 'Siegel'},
#  {'sum_amnt': '931926.96', 'recipname': 'Salamanca, Rafael'},
#  {'sum_amnt': '922530.03', 'recipname': 'Benjamin, Brian'},
#  {'sum_amnt': '870933.10', 'recipname': 'Morales, Dianne'},
#  {'sum_amnt': '855200', 'recipname': 'Voters of NYC, Inc.'},
#  {'sum_amnt': '832741.78', 'recipname': 'Gibson, Vanessa L'},
#  {'sum_amnt': '824500', 'recipname': 'Restaurant Action Alliance'},
#  {'sum_amnt': '815000', 'recipname': 'New Yorkers for a Balanced Albany'},
#  {'sum_amnt': '800151', 'recipname': 'Yassky'},
#  {'sum_amnt': '793772.49', 'recipname': 'Reynoso, Antonio'},
#  {'sum_amnt': '791396.11', 'recipname': 'Adams, Adrienne'},
#  {'sum_amnt': '790108.09', 'recipname': 'Van Bramer, James G'},
#  {'sum_amnt': '779500', 'recipname': 'A Better NY for All, LLC'},
#  {'sum_amnt': '768977.65', 'recipname': 'Caruso-Cabrera, Michelle'},
#  {'sum_amnt': '767848.83', 'recipname': 'Kallos, Benjamin J'},
#  {'sum_amnt': '767048.13', 'recipname': 'Richards, Donovan'},
#  {'sum_amnt': '762755.16', 'recipname': 'Green, Mark'},
#  {'sum_amnt': '760993.36', 'recipname': 'Lancman, Rory I'},
#  {'sum_amnt': '735659', 'recipname': 'DiBrienza'},
#  {'sum_amnt': '724961', 'recipname': 'Marshall'},
#  {'sum_amnt': '715492.83', 'recipname': 'Brannan, Justin'},
#  {'sum_amnt': '711222.22', 'recipname': 'Cornegy, Jr., Robert E'},
#  {'sum_amnt': '700706.27', 'recipname': 'Brewer, Gale A'},
#  {'sum_amnt': '694767.27',
#   'recipname': 'Working Families Party Campaign Committee'},
#  {'sum_amnt': '685000', 'recipname': 'Progress NYC'},
#  {'sum_amnt': '655376', 'recipname': 'Martinez'},
#  {'sum_amnt': '651906.83', 'recipname': 'Levine, Mark D'},
#  {'sum_amnt': '649075.62', 'recipname': 'Oddo, James S'},
#  {'sum_amnt': '647598.95', 'recipname': 'Myrie, Zellnor'},
#  {'sum_amnt': '641815.51', 'recipname': 'Mamdani, Zohran K'},
#  {'sum_amnt': '630213.78', 'recipname': 'Walden, James'},
#  {'sum_amnt': '625046', 'recipname': 'de Blasio'},
#  {'sum_amnt': '603084.48',
#   'recipname': '1199SEIU United Healthcare Workers East'},
#  {'sum_amnt': '600628', 'recipname': 'Lopez'},
#  {'sum_amnt': '590093', 'recipname': 'Vacca, James'},
#  {'sum_amnt': '588096.67', 'recipname': 'Hidary, Jack D'},
#  {'sum_amnt': '583500', 'recipname': 'Future NYC'},
#  {'sum_amnt': '583201.00', 'recipname': 'Powers, Keith'},
#  {'sum_amnt': '581387.95', 'recipname': 'Vallone, Paul A'},
#  {'sum_amnt': '577322.33', 'recipname': 'Recchia, Domenic M'},
#  {'sum_amnt': '571463', 'recipname': 'Espaillat'},
#  {'sum_amnt': '560141.60', 'recipname': 'Jackson, Robert'},
#  {'sum_amnt': '554000', 'recipname': 'NYCLASS'},
#  {'sum_amnt': '553584.51', 'recipname': 'Avella, Tony'},
#  {'sum_amnt': '550727', 'recipname': 'Liu'},
#  {'sum_amnt': '544160', 'recipname': 'Felder'},
#  {'sum_amnt': '544134.89', 'recipname': 'Mateo, Fernando A'},
#  {'sum_amnt': '543671', 'recipname': 'Badillo'},
#  {'sum_amnt': '539100', 'recipname': 'New Yorkers For Proven Leadership Inc'},
#  {'sum_amnt': '533169.77', 'recipname': 'Tolkin, Michael I'},
#  {'sum_amnt': '528882.67', 'recipname': 'Chou, Yen S'},
#  {'sum_amnt': '524100', 'recipname': 'Future Forward NYC, Inc.'},
#  {'sum_amnt': '524064', 'recipname': 'Freed'},
#  {'sum_amnt': '520500', 'recipname': 'NYC CLC Political Action Campaign Fund'},
#  {'sum_amnt': '519628.65', 'recipname': 'Cabrera, Fernando'},
#  {'sum_amnt': '517244.51', 'recipname': 'Kim, Kevin D'},
#  {'sum_amnt': '516605', 'recipname': 'Vallone, Jr.'},
#  {'sum_amnt': '515599', 'recipname': 'Ellner'},
#  {'sum_amnt': '513656.88', 'recipname': 'Rodriguez, Ydanis A'},
#  {'sum_amnt': '512911', 'recipname': 'Perkins'},
#  {'sum_amnt': '504874.91', 'recipname': 'Hikind, Yoni'},
#  {'sum_amnt': '497296', 'recipname': 'Small Business Coalition, Inc.'},
#  {'sum_amnt': '492453.41', 'recipname': 'Yeger, Kalman'},
#  {'sum_amnt': '489692.51', 'recipname': 'Build New York Fund'},
#  {'sum_amnt': '479569.11', 'recipname': 'Rajkumar, Jenifer'},
#  {'sum_amnt': '470759', 'recipname': 'Gennaro'},
#  {'sum_amnt': '455125.89', 'recipname': 'Dickens, Inez E'},
#  {'sum_amnt': '454467.37', 'recipname': 'Albanese, Sal F'},
#  {'sum_amnt': '451620.70', 'recipname': 'Hoylman, Brad'},
#  {'sum_amnt': '450000', 'recipname': 'Carpenters for Progress'},
#  {'sum_amnt': '446281', 'recipname': 'McMahon'},
#  {'sum_amnt': '445735', 'recipname': 'Quinn'},
#  {'sum_amnt': '445286', 'recipname': 'Gresser'},
#  {'sum_amnt': '440908.71', 'recipname': 'Marte, Christopher'},
#  {'sum_amnt': '436039.75', 'recipname': 'Matteo, Steven'},
#  {'sum_amnt': '431036.31', 'recipname': 'Simon, Jo Anne'},
#  {'sum_amnt': '428953.95', 'recipname': 'Pledge 2 Protect, Inc.'},
#  {'sum_amnt': '426022', 'recipname': 'Gerson'},
#  {'sum_amnt': '424967.97', 'recipname': 'Tilson, Whitney R'},
#  {'sum_amnt': '419494', 'recipname': 'Brennan, James F'},
#  {'sum_amnt': '413673', 'recipname': 'Comrie'},
#  {'sum_amnt': '410944.60', 'recipname': 'Narcisse, Mercedes'},
#  {'sum_amnt': '402138', 'recipname': 'Monserrate'},
#  {'sum_amnt': '395425', 'recipname': 'Manzano'},
#  {'sum_amnt': '394532.94', 'recipname': 'Tirschwell, Sara A'},
#  {'sum_amnt': '392300', 'recipname': 'Together For NYC'},
#  {'sum_amnt': '385646', 'recipname': 'Avella'},
#  {'sum_amnt': '382229', 'recipname': 'Torres, Ritchie J'},
#  {'sum_amnt': '378211.05', 'recipname': 'Weprin, Mark S'},
#  {'sum_amnt': '374319.59', 'recipname': 'Velazquez, Marjorie'},
#  {'sum_amnt': '362890.09', 'recipname': 'Salgado, Erick J'},
#  {'sum_amnt': '358035', 'recipname': 'Ferreras-Copeland, Julissa'},
#  {'sum_amnt': '355948.4', 'recipname': 'Rose, Deborah'},
#  {'sum_amnt': '348944.39', 'recipname': 'Parker, Kevin'},
#  {'sum_amnt': '347351', 'recipname': "O'Donovan"},
#  {'sum_amnt': '346899', 'recipname': 'Pheffer, Audrey I'},
#  {'sum_amnt': '346750.12', 'recipname': 'Comrie, Leroy G'},
#  {'sum_amnt': '345349.32', 'recipname': 'Paladino, Vickie'},
#  {'sum_amnt': '344960.19', 'recipname': 'Gentile, Vincent J'},
#  {'sum_amnt': '342877', 'recipname': 'Quart, Dan'},
#  {'sum_amnt': '342864.7', 'recipname': 'Edwards, Khari'},
#  {'sum_amnt': '338349', 'recipname': 'Reiter'},
#  {'sum_amnt': '337422', 'recipname': 'Rasiej'},
#  {'sum_amnt': '336872', 'recipname': 'Brewer'},
#  {'sum_amnt': '329367.88', 'recipname': 'Chin, Margaret'},
#  {'sum_amnt': '329093.30', 'recipname': 'Moya, Francisco P'},
#  {'sum_amnt': '318932.63', 'recipname': 'Koslowitz, Karen'},
#  {'sum_amnt': '318259.0', 'recipname': 'Rosenthal, Helen K'},
#  {'sum_amnt': '317309', 'recipname': 'Cohn'},
#  {'sum_amnt': '312991', 'recipname': 'Wright'},
#  {'sum_amnt': '312758.75',
#   'recipname': 'Unidos para Communidades Trabajadoras'},
#  {'sum_amnt': '312418.06', 'recipname': 'UFA STATE FIREPAC'},
#  {'sum_amnt': '312384.60', 'recipname': 'Arroyo, Maria'},
#  {'sum_amnt': '307289.20', 'recipname': 'Bottcher, Erik D'},
#  {'sum_amnt': '306000', 'recipname': 'New Generation of Leadership PAC'},
#  {'sum_amnt': '305888', 'recipname': 'Sears'},
#  {'sum_amnt': '305706.90', 'recipname': 'Deutsch, Chaim M'},
#  {'sum_amnt': '304581.39', 'recipname': 'Fossella, Vito J'},
#  {'sum_amnt': '303743.95', 'recipname': 'Gonzalez, Sara M'},
#  {'sum_amnt': '303105.36', 'recipname': 'Siegel, Norman H'},
#  {'sum_amnt': '301316', 'recipname': 'Peralta, Jose'},
#  {'sum_amnt': '301101.74', 'recipname': 'Hudson, Crystal'},
#  {'sum_amnt': '300852.01', 'recipname': 'Hanks, Kamillah M'},
#  {'sum_amnt': '299519.05', 'recipname': 'Allon, Tom F'},
#  {'sum_amnt': '288846', 'recipname': 'Gadson'},
#  {'sum_amnt': '287099', 'recipname': 'Rivera'},
#  {'sum_amnt': '285799.98', 'recipname': 'People for a Better New York'},
#  {'sum_amnt': '285080', 'recipname': 'Our City'},
#  {'sum_amnt': '283625', 'recipname': 'Gallagher'},
#  {'sum_amnt': '283587.5', 'recipname': 'Eugene, Mathieu'},
#  {'sum_amnt': '283084.83', 'recipname': 'Schulman, Lynn'},
#  {'sum_amnt': '275396.03', 'recipname': 'Brooks-Powers, Selvena N'},
#  {'sum_amnt': '274204.85', 'recipname': 'Van Bramer, Jimmy'},
#  {'sum_amnt': '273928', 'recipname': 'Reed'},
#  {'sum_amnt': '272518.19', 'recipname': 'Lander, Brad S'},
#  {'sum_amnt': '270850', 'recipname': 'New Yorkers United Committee'},
#  {'sum_amnt': '269335.96', 'recipname': 'Dromm, Daniel P'},
#  {'sum_amnt': '268173.55', 'recipname': 'Ung, Sandra'},
#  {'sum_amnt': '267049.84', 'recipname': 'Storch, Rachel'},
#  {'sum_amnt': '266990', 'recipname': 'Recchia'},
#  {'sum_amnt': '266967', 'recipname': 'James'},
#  {'sum_amnt': '266183', 'recipname': 'Eisland'},
#  {'sum_amnt': '266120.30', 'recipname': 'Chain, Heidi H'},
#  {'sum_amnt': '263431.65', 'recipname': 'Guerriero, Catherine'},
#  {'sum_amnt': '261296.99', 'recipname': 'Ulrich, Eric A'},
#  {'sum_amnt': '258774', 'recipname': 'Albanese'},
#  {'sum_amnt': '258716', 'recipname': 'Jackson'},
#  {'sum_amnt': '256570.16', 'recipname': 'Molinaro, James P'},
#  {'sum_amnt': '256428', 'recipname': 'Koppell'},
#  {'sum_amnt': '255212', 'recipname': 'Reyna'},
#  {'sum_amnt': '254544.93', 'recipname': 'Lee, Linda'},
#  {'sum_amnt': '253471', 'recipname': 'Addabbo'},
#  {'sum_amnt': '252831', 'recipname': 'Murphy'},
#  {'sum_amnt': '252112.66', 'recipname': 'Patel, Reshma'},
#  {'sum_amnt': '250656', 'recipname': 'Gennaro, James F'},
#  {'sum_amnt': '248319', 'recipname': 'Rodriguez'},
#  {'sum_amnt': '247888.77', 'recipname': 'Kagan, Ari'},
#  {'sum_amnt': '246795.80', 'recipname': 'Joseph, Rita C'},
#  {'sum_amnt': '246124.68', 'recipname': 'Kurland, Yetta'},
#  {'sum_amnt': '244112', 'recipname': 'Foster'},
#  {'sum_amnt': '243950', 'recipname': 'Hoylman'},
#  {'sum_amnt': '243605', 'recipname': 'Oddo'},
#  {'sum_amnt': '243163.39', 'recipname': 'Levin, Stephen T'},
#  {'sum_amnt': '240931', 'recipname': 'Chin'},
#  {'sum_amnt': '237568.32', 'recipname': 'Rodriguez, Robert J'},
#  {'sum_amnt': '236926', 'recipname': 'Baez'},
#  {'sum_amnt': '234605.61', 'recipname': 'Rivera, Joel'},
#  {'sum_amnt': '232725.52', 'recipname': 'Krishnan, Shekar'},
#  {'sum_amnt': '232358', 'recipname': 'Palma'},
#  {'sum_amnt': '232332.05', 'recipname': 'Farias, Amanda'},
#  {'sum_amnt': '232325.38', 'recipname': 'Cumbo, Laurie A'},
#  {'sum_amnt': '230130.25', 'recipname': 'Salamanca, Jr., Rafael'},
#  {'sum_amnt': '230000',
#   'recipname': 'The New York Progress and Protection PAC'},
#  {'sum_amnt': '227577.25', 'recipname': 'Abreu, Shaun'},
#  {'sum_amnt': '226514.11', 'recipname': 'Murphy, Mark'},
#  {'sum_amnt': '225808.5', 'recipname': 'Wymore, Mel'},
#  {'sum_amnt': '224798.39', 'recipname': 'Sanchez, Pierina A'},
#  {'sum_amnt': '224237.66', 'recipname': 'Caban, Tiffany'},
#  {'sum_amnt': '223500', 'recipname': 'Committee for Sensible Government'},
#  {'sum_amnt': '222155', 'recipname': 'Golden'},
#  {'sum_amnt': '222100', 'recipname': 'Road to Justice'},
#  {'sum_amnt': '221796.06', 'recipname': 'Won, Julie'},
#  {'sum_amnt': '220311.59', 'recipname': 'King, Andrew'},
#  {'sum_amnt': '220000', 'recipname': 'Amplify Her PAC'},
#  {'sum_amnt': '218391.38', 'recipname': 'Damplo, Susan M'},
#  {'sum_amnt': '217277', 'recipname': 'Constantinides, Costa'},
#  {'sum_amnt': '217159.03', 'recipname': 'Tischler, Harold'},
#  {'sum_amnt': '215826', 'recipname': 'Clarke'},
#  {'sum_amnt': '214492.04', 'recipname': 'Restler, Lincoln'},
#  {'sum_amnt': '213698.06', 'recipname': 'Hanif, Shahana'},
#  {'sum_amnt': '213169', 'recipname': 'Sanders, Jr.'},
#  {'sum_amnt': '213000', 'recipname': 'Rebuild NYC 2021'},
#  {'sum_amnt': '211879', 'recipname': 'Russo'},
#  {'sum_amnt': '211865.41', 'recipname': 'Miller, I. Daneek'},
#  {'sum_amnt': '206915', 'recipname': 'Stewart'},
#  {'sum_amnt': '205825.0', 'recipname': 'Treyger, Mark'},
#  {'sum_amnt': '204248.82', 'recipname': 'Menchaca, Carlos'},
#  {'sum_amnt': '204059.45', 'recipname': 'Boylan, Lindsey C'},
#  {'sum_amnt': '202957.90', 'recipname': 'Liftin, Terri'},
#  {'sum_amnt': '201877.81', 'recipname': 'DC37 Political Action Committee'},
#  {'sum_amnt': '197886.55', 'recipname': 'Rivera, Carlina L'},
#  {'sum_amnt': '196968.28', 'recipname': 'Stora, Skiboky'},
#  {'sum_amnt': '196883', 'recipname': 'Gentile'},
#  {'sum_amnt': '196443', 'recipname': 'Garodnick'},
#  {'sum_amnt': '195146', 'recipname': 'Rosenthal, Helen'},
#  {'sum_amnt': '190539.18', 'recipname': 'Sutton, Loree K'},
#  {'sum_amnt': '189483', 'recipname': 'Lappin'},
#  {'sum_amnt': '189229', 'recipname': 'Fidler'},
#  {'sum_amnt': '188209.63', 'recipname': 'Speranza, Martha'},
#  {'sum_amnt': '187763', 'recipname': 'Leffler'},
#  {'sum_amnt': '185707', 'recipname': 'Espinal, Jr., Rafael L'},
#  {'sum_amnt': '185176.40', 'recipname': 'Flowers, Joan E'},
#  {'sum_amnt': '184816', 'recipname': 'Dickens'},
#  {'sum_amnt': '183160', 'recipname': 'Felder, Simcha'},
#  {'sum_amnt': '182929.14', 'recipname': 'McDonald, George T'},
#  {'sum_amnt': '182701.5', 'recipname': 'Brewer, Gale'},
#  {'sum_amnt': '182129.66', 'recipname': 'Thompson, Josh'},
#  {'sum_amnt': '180777', 'recipname': 'Michels'},
#  {'sum_amnt': '177549', 'recipname': 'Vacca'},
#  {'sum_amnt': '176510.02', 'recipname': 'Riley, Kevin C'},
#  {'sum_amnt': '176187.08', 'recipname': 'Fox, Ede S'},
#  {'sum_amnt': '175750', 'recipname': 'City Action Coalition PAC'},
#  {'sum_amnt': '175542.91', 'recipname': 'Rivera, Carlina'},
#  {'sum_amnt': '174685.53', 'recipname': 'Ampry-Samuel, Alicka'},
#  {'sum_amnt': '174607.56', 'recipname': 'Holden, Robert F'},
#  {'sum_amnt': '173743.88', 'recipname': 'Chin, Margaret S'},
#  {'sum_amnt': '173675.02', 'recipname': 'Ignizio, Vincent M'},
#  {'sum_amnt': '172854', 'recipname': 'Dilan'},
#  {'sum_amnt': '172168.22', 'recipname': 'Brannan, Justin L'},
#  {'sum_amnt': '171323.37', 'recipname': 'Chang, Art'},
#  {'sum_amnt': '168775.57', 'recipname': 'Dinowitz, Eric'},
#  {'sum_amnt': '167484', 'recipname': 'Nelson'},
#  {'sum_amnt': '167155.52', 'recipname': 'Carr, David M'},
#  {'sum_amnt': '166415', 'recipname': 'Gotbaum, Betsy F'},
#  {'sum_amnt': '166044.21', 'recipname': 'Saperstein, Steven'},
#  {'sum_amnt': '165363.85', 'recipname': 'Choe, John'},
#  {'sum_amnt': '165000', 'recipname': 'New York Deserves Better PAC'},
#  {'sum_amnt': '164739.13', 'recipname': 'Constantinides, Costa G'},
#  {'sum_amnt': '164375', 'recipname': 'Caputo, Elizabeth R'},
#  {'sum_amnt': '162231.36', 'recipname': 'Ramos, Jessica'},
#  {'sum_amnt': '162125.77', 'recipname': 'Maisel, Alan'},
#  {'sum_amnt': '161939.04', 'recipname': 'Uemsou'},
#  {'sum_amnt': '157771', 'recipname': 'McMahon, Michael E'},
#  {'sum_amnt': '157152.30', 'recipname': 'Kellner, Micah Z'},
#  {'sum_amnt': '157101', 'recipname': 'Seabrook'},
#  {'sum_amnt': '157008.86', 'recipname': 'Cho, Ronnie S'},
#  {'sum_amnt': '156880.53', 'recipname': 'Mendez, Rosie'},
#  {'sum_amnt': '155471.54', 'recipname': 'Diaz, Sr., Ruben'},
#  {'sum_amnt': '154964', 'recipname': 'CVH Power'},
#  {'sum_amnt': '154577', 'recipname': 'Perez II, Radame'},
#  {'sum_amnt': '154265.27', 'recipname': 'Williams, Nantasha M'},
#  {'sum_amnt': '153319.14', 'recipname': 'Mealy, Darlene'},
#  {'sum_amnt': '153195.22', 'recipname': 'Aviles, Alexa'},
#  {'sum_amnt': '151503.93', 'recipname': 'Wang, Neng'},
#  {'sum_amnt': '151304.00', 'recipname': 'Grodenchik, Barry'},
#  {'sum_amnt': '149349', 'recipname': 'Cohen, Andrew J'},
#  {'sum_amnt': '148945', 'recipname': 'Lanza'},
#  {'sum_amnt': '148860.43', 'recipname': 'Zhuang, Susan'},
#  {'sum_amnt': '146855', 'recipname': 'Cheliotes'},
#  {'sum_amnt': '146772.57', 'recipname': 'Kim, Ronald T'},
#  {'sum_amnt': '146102.16', 'recipname': 'Nurse, Sandy'},
#  {'sum_amnt': '146083.84', 'recipname': 'Blake, Michael A'},
#  {'sum_amnt': '145513.99', 'recipname': 'Jung, S.J.'},
#  {'sum_amnt': '144539.90', 'recipname': 'Palma, Annabel'},
#  {'sum_amnt': '143439', 'recipname': 'Seminara'},
#  {'sum_amnt': '143207.38', 'recipname': 'Monserrate, Hiram'},
#  {'sum_amnt': '142410.37', 'recipname': 'Faulkner, Michel J'},
#  {'sum_amnt': '142373', 'recipname': 'Davis'},
#  {'sum_amnt': '141955', 'recipname': 'Biberaj, Ken'},
#  {'sum_amnt': '140323.59', 'recipname': 'Nampiaparampil, Devi E'},
#  {'sum_amnt': '140101.89', 'recipname': 'Sears, Helen'},
#  {'sum_amnt': '139898.39', 'recipname': 'Torres, Ritchie'},
#  {'sum_amnt': '139432.50', 'recipname': 'Louis, Farah'},
#  {'sum_amnt': '139243.08', 'recipname': 'Adams, Adrienne E'},
#  {'sum_amnt': '138899', 'recipname': 'Del Giorno'},
#  {'sum_amnt': '138713', 'recipname': 'Chen, Yi'},
#  {'sum_amnt': '138395', 'recipname': 'Straniere'},
#  {'sum_amnt': '138194', 'recipname': 'Ariola, Joann'},
#  {'sum_amnt': '136812.80', 'recipname': 'Morgan, Vincent S'},
#  {'sum_amnt': '136179', 'recipname': 'Barron'},
#  {'sum_amnt': '134760.74', 'recipname': 'De La Rosa, Carmen N'},
#  {'sum_amnt': '133989', 'recipname': 'Ravitz'},
#  {'sum_amnt': '133946', 'recipname': 'Marshall, Helen M'},
#  {'sum_amnt': '133538.41', 'recipname': 'Quaglione, John'},
#  {'sum_amnt': '133028', 'recipname': 'Ramadan, Zead'},
#  {'sum_amnt': '132958.14', 'recipname': 'Low, Jenny L'},
#  {'sum_amnt': '132484.18', 'recipname': 'Landis, Marc A'},
#  {'sum_amnt': '131862', 'recipname': 'Lisyanskiy, John'},
#  {'sum_amnt': '131112.89', 'recipname': 'Remauro, Leticia M'},
#  {'sum_amnt': '130655', 'recipname': 'Koslowitz'},
#  {'sum_amnt': '130206', 'recipname': 'Ferreras, Julissa'},
#  {'sum_amnt': '129142', 'recipname': 'Kaufman'},
#  {'sum_amnt': '128539', 'recipname': 'Gotbaum, Noah E'},
#  {'sum_amnt': '127605', 'recipname': 'Scissura, Carlo A'},
#  {'sum_amnt': '127587', 'recipname': 'Kalathara, Stanley J'},
#  {'sum_amnt': '127572', 'recipname': 'Brooks-Powers, Selvena'},
#  {'sum_amnt': '127363.72', 'recipname': 'Koppell, G. Oliver'},
#  {'sum_amnt': '127330', 'recipname': 'Crowley'},
#  {'sum_amnt': '127237', 'recipname': 'Luciano'},
#  {'sum_amnt': '126306.58', 'recipname': 'Vernikov, Inna'},
#  {'sum_amnt': '126301', 'recipname': 'Wright Jr., Isaac'},
#  {'sum_amnt': '126065', 'recipname': 'Hoylman-Sigal, Brad'},
#  {'sum_amnt': '125800', 'recipname': 'Fighting for our Future PAC'},
#  {'sum_amnt': '125450', 'recipname': 'Grodenchik, Barry S'},
#  {'sum_amnt': '124549', 'recipname': 'Quart'},
#  {'sum_amnt': '124118', 'recipname': 'Baryab, Fatima'},
#  {'sum_amnt': '123552', 'recipname': 'Espada, Jr.'},
#  {'sum_amnt': '122772.74', 'recipname': 'Iannece, Jerry M'},
#  {'sum_amnt': '121142.23', 'recipname': 'Lewinsohn, Elizabeth'},
#  {'sum_amnt': '120892.35', 'recipname': 'Sun, Calvin D'},
#  {'sum_amnt': '120817', 'recipname': 'White, Jr.'},
#  {'sum_amnt': '120490', 'recipname': 'Serrano'},
#  {'sum_amnt': '120278.00', 'recipname': 'Jordan, Kristin R'},
#  {'sum_amnt': '118726', 'recipname': 'Torres'},
#  {'sum_amnt': '118691.8', 'recipname': 'Davila, Maritza'},
#  {'sum_amnt': '117698.67', 'recipname': 'Reyna, Diana'},
#  {'sum_amnt': '116633.73', 'recipname': 'Oberman, Igor'},
#  {'sum_amnt': '116537.48', 'recipname': 'Osse, Chi A'},
#  {'sum_amnt': '116323.02', 'recipname': 'Ampry-Samuel, Alicka T'},
#  {'sum_amnt': '115454.11', 'recipname': "O'Leary, Brent M"},
#  {'sum_amnt': '114992', 'recipname': 'Kavanagh'},
#  {'sum_amnt': '114509.63', 'recipname': 'Griffith, Mark W'},
#  {'sum_amnt': '113968', 'recipname': 'Mealy'},
#  {'sum_amnt': '113223.12', 'recipname': 'El-Yateem, Khader'},
#  {'sum_amnt': '112655.31', 'recipname': 'Cassino, Anthony P'},
#  {'sum_amnt': '112571.14', 'recipname': 'Quiroz, Alfonso'},
#  {'sum_amnt': '112409', 'recipname': 'Levine'},
#  {'sum_amnt': '112404', 'recipname': 'Gonzalez'},
#  {'sum_amnt': '112306', 'recipname': 'Mitchell, Kenneth C'},
#  {'sum_amnt': '111566', 'recipname': 'Herbert, Anthony L'},
#  {'sum_amnt': '111463.36', 'recipname': 'Wu, James M'},
#  {'sum_amnt': '111365.08', 'recipname': 'Tan, Alison'},
#  {'sum_amnt': '111183', 'recipname': 'Carroll'},
#  {'sum_amnt': '110878.93', 'recipname': 'Skaller, Josh'},
#  {'sum_amnt': '110490.53', 'recipname': 'Cooper, Debra'},
#  {'sum_amnt': '110263.32', 'recipname': 'Silver, Mary'},
#  {'sum_amnt': '110194.43', 'recipname': 'Salaam, Yusef'},
#  {'sum_amnt': '109171.79', 'recipname': 'Fernandez, Nathalia'},
#  {'sum_amnt': '109029.06', 'recipname': 'Tapia, Yudelka'},
#  {'sum_amnt': '108995', 'recipname': 'Ognibene'},
#  {'sum_amnt': '108776.54', 'recipname': 'Council, Kimberly'},
#  {'sum_amnt': '108508', 'recipname': 'Mendez'},
#  {'sum_amnt': '108097', 'recipname': 'Mark-Viverito'},
#  {'sum_amnt': '108068', 'recipname': 'Banks'},
#  {'sum_amnt': '108043.46', 'recipname': 'Ayala, Diana'},
#  {'sum_amnt': '107302', 'recipname': 'Kim, PJ'},
#  {'sum_amnt': '107091.60', 'recipname': 'Powell, Hettie V'},
#  {'sum_amnt': '106607', 'recipname': 'Norman'},
#  {'sum_amnt': '105952', 'recipname': 'Singh, Swaranjit'},
#  {'sum_amnt': '105730.62', 'recipname': 'Foster, Helen Diane'},
#  {'sum_amnt': '105588', 'recipname': 'Taitt'},
#  {'sum_amnt': '104653.63', 'recipname': 'Halloran, Daniel J'},
#  {'sum_amnt': '104247', 'recipname': 'Lizardo'},
#  {'sum_amnt': '103855', 'recipname': 'Baldeo'},
#  {'sum_amnt': '103797', 'recipname': 'Shafran, Austin I'},
#  {'sum_amnt': '103609', 'recipname': 'Vann'},
#  {'sum_amnt': '103575.42', 'recipname': 'Scavo, Theresa R'},
#  {'sum_amnt': '102820.08', 'recipname': 'Aronson, Vanessa T'},
#  {'sum_amnt': '102509', 'recipname': 'Brennan'},
#  {'sum_amnt': '101556', 'recipname': 'Leavitt, Marc C'},
#  {'sum_amnt': '101553', 'recipname': 'Zinberg'},
#  {'sum_amnt': '101416.0', 'recipname': 'Vann, Albert'},
#  {'sum_amnt': '101355', 'recipname': 'Vassos'},
#  {'sum_amnt': '100432.03', 'recipname': 'Li, Gigi'},
#  {'sum_amnt': '100355', 'recipname': 'McManus'},
#  {'sum_amnt': '99842.22', 'recipname': 'Zuckerman, Bob'},
#  {'sum_amnt': '99100.59', 'recipname': 'Esposito, Gerald A'},
#  {'sum_amnt': '98465.72', 'recipname': 'Raymond, Edwin'},
#  {'sum_amnt': '97960', 'recipname': 'Grodenchik'},
#  {'sum_amnt': '97709', 'recipname': 'Stabile'},
#  {'sum_amnt': '96974.02', 'recipname': 'Gutierrez, Jennifer'},
#  {'sum_amnt': '96741.16', 'recipname': 'Menchaca, Carlos R'},
#  {'sum_amnt': '96691.3', 'recipname': 'McNickle, Chris J'},
#  {'sum_amnt': '96542.71', 'recipname': 'Kepi, Marko'},
#  {'sum_amnt': '96034.01', 'recipname': 'Rivera, William'},
#  {'sum_amnt': '95501.76', 'recipname': 'Dobrin, Todd A'},
#  {'sum_amnt': '95058', 'recipname': 'Jennings'},
#  {'sum_amnt': '94657.19', 'recipname': 'Gianaris, Michael N'},
#  {'sum_amnt': '94494.6', 'recipname': 'Ayala, Diana I'},
#  {'sum_amnt': '93494.5', 'recipname': 'Schulman, Lynn C'},
#  {'sum_amnt': '93115.04', 'recipname': 'Maron, Maud'},
#  {'sum_amnt': '92919', 'recipname': 'Dromm, Daniel'},
#  {'sum_amnt': '92198.73', 'recipname': 'Capano, Robert P'},
#  {'sum_amnt': '91829', 'recipname': 'Lobo'},
#  {'sum_amnt': '91575.77', 'recipname': 'Gerson, Alan J'},
#  {'sum_amnt': '90648', 'recipname': 'Bashner, Richard S'},
#  {'sum_amnt': '90632.96', 'recipname': 'Doyle, John C'},
#  {'sum_amnt': '89726.74', 'recipname': 'Saffran, Dennis J'},
#  {'sum_amnt': '89208.64', 'recipname': 'Barnes, Amoy K'},
#  {'sum_amnt': '89144', 'recipname': 'Borelli, Joseph'},
#  {'sum_amnt': '88988', 'recipname': 'Powell, Adam'},
#  {'sum_amnt': '88925', 'recipname': 'Cornelius'},
#  {'sum_amnt': '88825.0', 'recipname': 'White, Jr., Thomas'},
#  {'sum_amnt': '88460', 'recipname': 'Pu-Folkes'},
#  {'sum_amnt': '88325.71', 'recipname': 'Stevens, Althea V'},
#  {'sum_amnt': '87981.48', 'recipname': 'Singh, Felicia'},
#  {'sum_amnt': '87122', 'recipname': 'Fidler, Lewis A'},
#  {'sum_amnt': '87050', 'recipname': 'Verrazzano Victory Alliance'},
#  {'sum_amnt': '87041', 'recipname': 'Conley'},
#  {'sum_amnt': '87030', 'recipname': 'Sasson, Isaac M'},
#  {'sum_amnt': '86705.06', 'recipname': 'Hollingsworth, Michael D'},
#  {'sum_amnt': '86596.25', 'recipname': 'Feliz, Oswald'},
#  {'sum_amnt': '86571', 'recipname': 'Ortiz, Felix W'},
#  {'sum_amnt': '86466.22', 'recipname': 'Rein, Briget'},
#  {'sum_amnt': '85571', 'recipname': 'Mattera'},
#  {'sum_amnt': '84723', 'recipname': 'Morisete-Romero'},
#  {'sum_amnt': '84305', 'recipname': 'Feerick, Deirdre A'},
#  {'sum_amnt': '84004.41', 'recipname': 'Clark, Jason'},
#  {'sum_amnt': '83351', 'recipname': 'Jones, Anthony T'},
#  {'sum_amnt': '83187', 'recipname': 'Wills, Ruben W'},
#  {'sum_amnt': '83148', 'recipname': 'Farrell'},
#  {'sum_amnt': '82397.90', 'recipname': 'Allen-Cummings, Marti G'},
#  {'sum_amnt': '82320.84', 'recipname': 'Butler, Henry'},
#  {'sum_amnt': '82298.25', 'recipname': 'Markell, Debra'},
#  {'sum_amnt': '82195', 'recipname': 'Duane, John F'},
#  {'sum_amnt': '81984.44', 'recipname': 'West, Brandon'},
#  {'sum_amnt': '81962.16', 'recipname': 'Honig, Rachel L'},
#  {'sum_amnt': '81902.76', 'recipname': 'Graziano, Paul D'},
#  {'sum_amnt': '81621', 'recipname': 'Beys'},
#  {'sum_amnt': '81190', 'recipname': 'Stewart, Kendall B'},
#  {'sum_amnt': '81128.90', 'recipname': 'Fernandez, Angela'},
#  {'sum_amnt': '80918', 'recipname': 'Batchu, Sarah L'},
#  {'sum_amnt': '80427', 'recipname': 'Foglia'},
#  {'sum_amnt': '80401', 'recipname': 'Golub'},
#  {'sum_amnt': '80380', 'recipname': 'Heyer, II, John L'},
#  {'sum_amnt': '80170', 'recipname': 'Chen'},
#  {'sum_amnt': '80010.17', 'recipname': 'Barron, Inez D'},
#  {'sum_amnt': '79775', 'recipname': 'Baez, Maria'},
#  {'sum_amnt': '79407', 'recipname': 'Tsabar'},
#  {'sum_amnt': '79092.95', 'recipname': 'Lee, Susan'},
#  {'sum_amnt': '79066', 'recipname': 'Hoffnung, Ari M'},
#  {'sum_amnt': '78704.46', 'recipname': 'Thies, Evan R'},
#  {'sum_amnt': '78496', 'recipname': 'Bloch'},
#  {'sum_amnt': '78463', 'recipname': 'Lester'},
#  {'sum_amnt': '78065.11', 'recipname': 'Torres, Tommy'},
#  {'sum_amnt': '77773', 'recipname': 'Sanders, Jr., James J'},
#  {'sum_amnt': '77506', 'recipname': 'Harary, Rebecca S'},
#  {'sum_amnt': '77225.34', 'recipname': 'Maloney, Virginia'},
#  {'sum_amnt': '77188.14', 'recipname': 'Rahman, Mujib U'},
#  {'sum_amnt': '77134.67', 'recipname': 'Sierra, Carlos M'},
#  {'sum_amnt': '76635', 'recipname': 'Tong, Nancy'},
#  {'sum_amnt': '76526.11', 'recipname': 'Malave, Ismael'},
#  {'sum_amnt': '76457', 'recipname': 'Newton, Judy D'},
#  {'sum_amnt': '76159', 'recipname': 'Saunders'},
#  {'sum_amnt': '76105', 'recipname': 'Farrell, Jr., Herman D'},
#  {'sum_amnt': '75849.39', 'recipname': 'Payne-Hanks, Kamillah M'},
#  {'sum_amnt': '75650', 'recipname': 'Montano'},
#  {'sum_amnt': '75644.84', 'recipname': 'Tucker-Pryor, Tiffany A'},
#  {'sum_amnt': '75610', 'recipname': 'Colon'},
#  {'sum_amnt': '75567', 'recipname': 'Hoffnung'},
#  {'sum_amnt': '75289.3', 'recipname': 'Barron, Charles'},
#  {'sum_amnt': '74968.75', 'recipname': 'Marmorato, Kristy'},
#  {'sum_amnt': '74802.3', 'recipname': 'Garcia, Johanna'},
#  {'sum_amnt': '74425', 'recipname': 'Macron, Mark A'},
#  {'sum_amnt': '74319.47', 'recipname': 'Handy-Hilliard, Kenya'},
#  {'sum_amnt': '74099.38', 'recipname': 'Abreu, Adolfo'},
#  {'sum_amnt': '73405', 'recipname': 'Fratta'},
#  {'sum_amnt': '73358.90', 'recipname': 'Honor, Lorraine'},
#  {'sum_amnt': '73301', 'recipname': 'Storobin, David'},
#  {'sum_amnt': '73178.65', 'recipname': 'Bagga, Amit S'},
#  {'sum_amnt': '72967.86', 'recipname': 'Potosky, Toba'},
#  {'sum_amnt': '72540', 'recipname': 'Seminerio'},
#  {'sum_amnt': '72430.49', 'recipname': 'Lucas, Nikki'},
#  {'sum_amnt': '72313', 'recipname': 'Pheffer'},
#  {'sum_amnt': '72084', 'recipname': 'Jefferson'},
#  {'sum_amnt': '71765.91', 'recipname': 'Foy, Kirsten J'},
#  {'sum_amnt': '71753', 'recipname': 'Montague'},
#  {'sum_amnt': '71747', 'recipname': 'Pai, Yu-Ching James'},
#  {'sum_amnt': '71560.13', 'recipname': 'Passannante-Derr, Maria'},
#  {'sum_amnt': '71500', 'recipname': 'People Enhancing New York'},
#  {'sum_amnt': '71473.5', 'recipname': 'Sheikh, Helal A'},
#  {'sum_amnt': '71213', 'recipname': 'Johnson'},
#  {'sum_amnt': '71201', 'recipname': 'Adams'},
#  {'sum_amnt': '70961.51', 'recipname': 'Schachter, Bessie R'},
#  {'sum_amnt': '70922.00', 'recipname': 'Ognibene, Thomas V'},
#  {'sum_amnt': '70523', 'recipname': 'Santiago'},
#  {'sum_amnt': '70284.89', 'recipname': 'Hantzopoulos, Evie'},
#  {'sum_amnt': '69979.49', 'recipname': 'Sanchez, Justin E'},
#  {'sum_amnt': '69384.66', 'recipname': 'Young, Ellen'},
#  {'sum_amnt': '69228', 'recipname': 'Abreu, Randy'},
#  {'sum_amnt': '68972.20', 'recipname': 'Lee, Richard J'},
#  {'sum_amnt': '68950', 'recipname': 'Simanowitz, Michael'},
#  {'sum_amnt': '68787.69', 'recipname': 'Cohen, Daniel M'},
#  {'sum_amnt': '68680', 'recipname': 'Lopez, Vito J'},
#  {'sum_amnt': '68663', 'recipname': 'Pugliese'},
#  {'sum_amnt': '68335.42', 'recipname': 'Thomas, Saundra P'},
#  {'sum_amnt': '68086', 'recipname': 'Brazela, Gardy'},
#  {'sum_amnt': '67876', 'recipname': 'Betancourt Jr'},
#  {'sum_amnt': '67858.98', 'recipname': 'Banks, Christopher W'},
#  {'sum_amnt': '67610.19', 'recipname': 'Carroll, Kevin Peter'},
#  {'sum_amnt': '67602', 'recipname': 'Rupnarain'},
#  {'sum_amnt': '67578.90', 'recipname': 'Lind, Sara K'},
#  {'sum_amnt': '67535', 'recipname': 'Parker'},
#  {'sum_amnt': '67442.23', 'recipname': 'Concannon, Joseph R'},
#  {'sum_amnt': '67425.93', 'recipname': 'Adams, Elizabeth'},
#  {'sum_amnt': '67185.99', 'recipname': 'Council, Kimberly N'},
#  {'sum_amnt': '66879', 'recipname': 'Van Bramer'},
#  {'sum_amnt': '66761.23', 'recipname': 'Garcia, Elvin'},
#  {'sum_amnt': '66624', 'recipname': 'Aronov, David'},
#  {'sum_amnt': '66351.26', 'recipname': 'Taylor, Joycelyn'},
#  {'sum_amnt': '66047.7', 'recipname': 'Freeland, Billy'},
#  {'sum_amnt': '65980', 'recipname': 'Diamondstone, Kenneth A'},
#  {'sum_amnt': '65529.33', 'recipname': 'Epstein, Harvey D'},
#  {'sum_amnt': '65373', 'recipname': 'Park'},
#  {'sum_amnt': '65247.25', 'recipname': 'People for a Better NY'},
#  {'sum_amnt': '65241', 'recipname': 'Hikind'},
#  {'sum_amnt': '65229', 'recipname': 'Behar, Steve'},
#  {'sum_amnt': '65227', 'recipname': 'Denis'},
#  {'sum_amnt': '65132', 'recipname': 'Bader'},
#  {'sum_amnt': '65104.73', 'recipname': 'Stanton, Cliff I'},
#  {'sum_amnt': '64916', 'recipname': 'Pierson, Stephen E'},
#  {'sum_amnt': '64855.43', 'recipname': 'Bottcher, Erik'},
#  {'sum_amnt': '64668.37', 'recipname': 'Escoffery-Bey, Mark'},
#  {'sum_amnt': '64640', 'recipname': 'Prentzas, Constantinos'},
#  {'sum_amnt': '64601', 'recipname': 'Tejada, Luis M'},
#  {'sum_amnt': '64580', 'recipname': 'Giovinazzo, Lisa E'},
#  {'sum_amnt': '64272.06', 'recipname': 'McCabe, Liam A'},
#  {'sum_amnt': '64079', 'recipname': 'Chan, Wai Yee'},
#  {'sum_amnt': '63906', 'recipname': 'Chandra, Ashok'},
#  {'sum_amnt': '63778', 'recipname': 'Andrews, Jr.'},
#  {'sum_amnt': '63597.30', 'recipname': 'Gulluscio, Frank P'},
#  {'sum_amnt': '63500', 'recipname': 'LATINO VICTORY FUND NYC'},
#  {'sum_amnt': '63232', 'recipname': 'Brodsky'},
#  {'sum_amnt': '63210', 'recipname': 'Graham, Yvonne J'},
#  {'sum_amnt': '63176', 'recipname': 'Taveras'},
#  {'sum_amnt': '63050', 'recipname': 'Boyland, Sr.'},
#  {'sum_amnt': '62821.39', 'recipname': 'Kornberg, Maya'},
#  {'sum_amnt': '62737', 'recipname': 'Smyth, Dermot'},
#  {'sum_amnt': '62625', 'recipname': 'United Uniformed Workers of New York'},
#  {'sum_amnt': '61956', 'recipname': 'Ruiz, Jr.'},
#  {'sum_amnt': '61887.97', 'recipname': 'Gordillo, Andrea'},
#  {'sum_amnt': '61833', 'recipname': 'Benjamin'},
#  {'sum_amnt': '61803', 'recipname': 'King'},
#  {'sum_amnt': '61661.55', 'recipname': 'Bravo, Ischia'},
#  {'sum_amnt': '61395', 'recipname': 'Palmer'},
#  {'sum_amnt': '61392.99', 'recipname': 'Krebs, Justin M'},
#  {'sum_amnt': '60836', 'recipname': 'Brown'},
#  {'sum_amnt': '60802', 'recipname': 'Shulman'},
#  {'sum_amnt': '60785', 'recipname': 'Thompson, Mark P'},
#  {'sum_amnt': '60506.85', 'recipname': 'Moscaritolo, Kim'},
#  {'sum_amnt': '60011.06', 'recipname': 'Cranston, Donald J'},
#  {'sum_amnt': '59895', 'recipname': 'Kearney'},
#  {'sum_amnt': '59666.16', 'recipname': 'Eisenbach, David'},
#  {'sum_amnt': '59579', 'recipname': 'Nussbaum, Dale'},
#  {'sum_amnt': '59554.61', 'recipname': 'Cunningham, Brian-Christoph A'},
#  {'sum_amnt': '59408', 'recipname': 'Omura, Jeffrey'},
#  {'sum_amnt': '59334.56', 'recipname': 'Adler, Amber'},
#  {'sum_amnt': '59146', 'recipname': 'Reich'},
#  {'sum_amnt': '58944.89', 'recipname': 'Ejaz, Salim'},
#  {'sum_amnt': '58893.11', 'recipname': 'Diaz, Darma V'},
#  {'sum_amnt': '58877.84', 'recipname': 'Lynch, Stacy R'},
#  {'sum_amnt': '58854', 'recipname': 'Johnson, James J'},
#  {'sum_amnt': '58655.7', 'recipname': 'Pierre, Josue'},
#  {'sum_amnt': '58531.74', 'recipname': 'Burnett, John L'},
#  {'sum_amnt': '58524.63', 'recipname': 'Schwartz, Dylan M'},
#  {'sum_amnt': '58335', 'recipname': 'Rose'},
#  {'sum_amnt': '58332', 'recipname': 'Gutnik'},
#  {'sum_amnt': '58174', 'recipname': 'Scissura'},
#  {'sum_amnt': '57926', 'recipname': 'Vernet'},
#  {'sum_amnt': '57517.62', 'recipname': 'Miller-Whitehead, Lamor'},
#  {'sum_amnt': '57337.00', 'recipname': 'Sepulveda, Luis R'},
#  {'sum_amnt': '57238', 'recipname': 'Sementilli'},
#  {'sum_amnt': '57155.24', 'recipname': 'Francis, Quanda S'},
#  {'sum_amnt': '56910.9', 'recipname': 'Hartzog, Edward A'},
#  {'sum_amnt': '56910', 'recipname': 'Siegal'},
#  {'sum_amnt': '56890', 'recipname': 'Saffran'},
#  {'sum_amnt': '56843', 'recipname': 'Friedrich, Robert'},
#  {'sum_amnt': '56789.35', 'recipname': 'Luisi, John'},
#  {'sum_amnt': '56780.90', 'recipname': 'Quaglione, John F'},
#  {'sum_amnt': '56270', 'recipname': 'Cooper-Gregory'},
#  {'sum_amnt': '56240', 'recipname': 'Cerini, John'},
#  {'sum_amnt': '55912', 'recipname': 'Martinez, Miguel'},
#  {'sum_amnt': '55669', 'recipname': 'Seddio, Frank R'},
#  {'sum_amnt': '55575', 'recipname': 'Dilan, Erik M'},
#  {'sum_amnt': '55532.82', 'recipname': 'Mancuso, John'},
#  {'sum_amnt': '55381.7', 'recipname': 'Mcintosh Green, Isis'},
#  {'sum_amnt': '55195.42', 'recipname': 'Perkins, Bill'},
#  {'sum_amnt': '55004.25', 'recipname': 'Nelson, Michael C'},
#  {'sum_amnt': '54902', 'recipname': 'Simon, Lew M'},
#  {'sum_amnt': '54769', 'recipname': 'Abraham, Isaac'},
#  {'sum_amnt': '54314.63', 'recipname': 'Alabi, Olanike T'},
#  {'sum_amnt': '54114.79', 'recipname': 'Materna, Janine'},
#  {'sum_amnt': '54079.86', 'recipname': 'Bae, Christopher'},
#  {'sum_amnt': '53667', 'recipname': 'Hui'},
#  {'sum_amnt': '53565.95', 'recipname': 'Linares, Guillermo'},
#  {'sum_amnt': '53253.85', 'recipname': 'Shimamura, Tricia'},
#  {'sum_amnt': '53152.90', 'recipname': 'Toboroff, Jacqueline'},
#  {'sum_amnt': '53083.81', 'recipname': 'Pepitone, William'},
#  {'sum_amnt': '53058.55', 'recipname': 'Lamorte, Rebecca'},
#  {'sum_amnt': '52790.00', 'recipname': 'Chen, Jin Liang'},
#  {'sum_amnt': '52708.0', 'recipname': 'Shafran, Austin'},
#  {'sum_amnt': '52560.0', 'recipname': 'Taylor, Martha'},
#  {'sum_amnt': '52492.77', 'recipname': 'Rosser, Mario'},
#  {'sum_amnt': '52343.78', 'recipname': 'Mailman, Jeffrey S'},
#  {'sum_amnt': '52325', 'recipname': 'Hylton'},
#  {'sum_amnt': '52190.71', 'recipname': 'Kim, Hailie'},
#  {'sum_amnt': '52137.58', 'recipname': 'Lantigua, Manuel'},
#  {'sum_amnt': '52062.02', 'recipname': 'Diallo, Abdourahamane'},
#  {'sum_amnt': '52040.28', 'recipname': 'Young, Ebony R'},
#  {'sum_amnt': '52028.83', 'recipname': 'Johnson, Joyce S'},
#  {'sum_amnt': '51880', 'recipname': 'Borelli, Joseph C'},
#  {'sum_amnt': '51870', 'recipname': 'Aquino, Fernando A'},
#  {'sum_amnt': '51804.15', 'recipname': 'Kaur, Jaslin'},
#  {'sum_amnt': '51737', 'recipname': 'Butler, Henry L'},
#  {'sum_amnt': '51709', 'recipname': 'Lewis'},
#  {'sum_amnt': '51687.93', 'recipname': 'Brisport, Jabari'},
#  {'sum_amnt': '51482.74', 'recipname': 'Paul, Shirley S'},
#  {'sum_amnt': '51294', 'recipname': 'Singh, Japneet'},
#  {'sum_amnt': '50865', 'recipname': 'Kavadas, Constantine E'},
#  {'sum_amnt': '50547.25', 'recipname': 'Cyperstein, Avi'},
#  {'sum_amnt': '50453.27', 'recipname': 'Schwartz, Arthur Z'},
#  {'sum_amnt': '50430', 'recipname': 'McKenzie, Dexter A'},
#  {'sum_amnt': '50304.32', 'recipname': 'Cardona, Ralina M'},
#  {'sum_amnt': '50071.96', 'recipname': 'David, Richard'},
#  {'sum_amnt': '50000', 'recipname': 'Kim, Jhong'},
#  {'sum_amnt': '49887.92', 'recipname': 'Hunley-Adossa, Delia M'},
#  {'sum_amnt': '49758', 'recipname': 'Bondy, Faith'},
#  {'sum_amnt': '49683.64', 'recipname': 'Ortega, Corey'},
#  {'sum_amnt': '49651.19', 'recipname': 'Banks, Christopher'},
#  {'sum_amnt': '49647', 'recipname': 'Schneider, Douglas'},
#  {'sum_amnt': '49609', 'recipname': 'Havranek, George F'},
#  {'sum_amnt': '49552.82', 'recipname': 'Sanchez, Raymond'},
#  {'sum_amnt': '49551.6', 'recipname': 'Ardila, Juan D'},
#  {'sum_amnt': '49539.68', 'recipname': 'Waterman, Robert M'},
#  {'sum_amnt': '49477', 'recipname': 'Paterson'},
#  {'sum_amnt': '49356', 'recipname': 'Moore, Tahirah A'},
#  {'sum_amnt': '49178', 'recipname': 'Jung, Ursila'},
#  {'sum_amnt': '49175', 'recipname': 'Luisi'},
#  {'sum_amnt': '49035', 'recipname': 'Reddick'},
#  {'sum_amnt': '48255.53', 'recipname': 'Valdes, Delvis'},
#  {'sum_amnt': '48239', 'recipname': 'Haber'},
#  {'sum_amnt': '48024', 'recipname': 'Diamondstone'},
#  {'sum_amnt': '48022.52', 'recipname': 'Taitt, Samuel A'},
#  {'sum_amnt': '47787.59', 'recipname': 'Tran, Carolyn T'},
#  {'sum_amnt': '47755', 'recipname': 'Simon'},
#  {'sum_amnt': '47552', 'recipname': 'Duncan, Michael R'},
#  {'sum_amnt': '47339', 'recipname': 'Purcell'},
#  {'sum_amnt': '47153.00', 'recipname': 'Talen, Billy'},
#  {'sum_amnt': '47136', 'recipname': 'Adams, Kenneth G'},
#  {'sum_amnt': '47103.98', 'recipname': 'Raymond, Pia'},
#  {'sum_amnt': '46989', 'recipname': 'Lasher'},
#  {'sum_amnt': '46969', 'recipname': 'Wai, Sidique A'},
#  {'sum_amnt': '46900', 'recipname': 'Weprin, Mark'},
#  {'sum_amnt': '46842.18', 'recipname': 'Chirico, Vincenzo'},
#  {'sum_amnt': '46617.73', 'recipname': 'Cleare, Cordell'},
#  {'sum_amnt': '46149', 'recipname': 'Ragusa'},
#  {'sum_amnt': '46128', 'recipname': 'Thakral'},
#  {'sum_amnt': '46102', 'recipname': 'Rivera, Joel R'},
#  {'sum_amnt': '46030.48', 'recipname': 'Ogunleye, Ranti'},
#  {'sum_amnt': '45830', 'recipname': 'Williams'},
#  {'sum_amnt': '45815', 'recipname': 'Bullaro, Leonardo'},
#  {'sum_amnt': '45795', 'recipname': 'Bernace'},
#  {'sum_amnt': '45745', 'recipname': 'Spalter'},
#  {'sum_amnt': '45616.84', 'recipname': 'Sherman, Stuart C'},
#  {'sum_amnt': '45462', 'recipname': 'Tan, Ying'},
#  {'sum_amnt': '45450', 'recipname': 'Syed, Imtiaz S'},
#  {'sum_amnt': '45433', 'recipname': 'Waterman, Robert'},
#  {'sum_amnt': '45380.5', 'recipname': 'Schwartz, Robert'},
#  {'sum_amnt': '45371', 'recipname': 'Cesnik'},
#  {'sum_amnt': '45075', 'recipname': 'Zapiti'},
#  {'sum_amnt': '45015.16', 'recipname': 'Chen, Hailing'},
#  {'sum_amnt': '44975', 'recipname': 'Voters for Substantial Equivalency'},
#  {'sum_amnt': '44915.19', 'recipname': 'Boghosian Murphy, Leslie'},
#  {'sum_amnt': '44532.83', 'recipname': 'Alvarez, Pedro'},
#  {'sum_amnt': '44424.87', 'recipname': 'Caruana, Craig N'},
#  {'sum_amnt': '44308', 'recipname': 'Del Rio, Richard'},
#  {'sum_amnt': '44224', 'recipname': 'Greco, Jr.'},
#  {'sum_amnt': '44201.54', 'recipname': 'Garland, David P'},
#  {'sum_amnt': '44118.81', 'recipname': 'Wetzler, Benjamin D'},
#  {'sum_amnt': '44037.68', 'recipname': 'Meloni, Antonio M'},
#  {'sum_amnt': '43881.76', 'recipname': 'Felder, Ethan'},
#  {'sum_amnt': '43846', 'recipname': 'Ravelo, Samuel'},
#  {'sum_amnt': '43593', 'recipname': "O'Malley"},
#  {'sum_amnt': '43568.75', 'recipname': 'Gleason, Peter J'},
#  {'sum_amnt': '43536', 'recipname': 'Olivera, Deidre L'},
#  {'sum_amnt': '43303', 'recipname': 'Thomas-Henry, Shanel'},
#  {'sum_amnt': '42935.05', 'recipname': 'Marano, John C'},
#  {'sum_amnt': '42922', 'recipname': 'Foldenauer, Aaron S'},
#  {'sum_amnt': '42882.29', 'recipname': 'Richards, Donovan J'},
#  {'sum_amnt': '42806.43', 'recipname': 'Halasa, Marni'},
#  {'sum_amnt': '42761', 'recipname': 'Hall'},
#  {'sum_amnt': '42399.58', 'recipname': 'Santosuosso, Kayla'},
#  {'sum_amnt': '42353', 'recipname': 'Martin, Abigail J'},
#  {'sum_amnt': '42260.99', 'recipname': 'Vasquez, Jorge L'},
#  {'sum_amnt': '42220', 'recipname': 'Marchant'},
#  {'sum_amnt': '41954.01', 'recipname': 'Lin, Yu'},
#  {'sum_amnt': '41830.5', 'recipname': 'Otto, Mark T'},
#  {'sum_amnt': '41823.92', 'recipname': 'Raga, Steven'},
#  {'sum_amnt': '41731.81', 'recipname': 'Coleman, Jess K'},
#  {'sum_amnt': '41640.85', 'recipname': 'Cohen, Michael L'},
#  {'sum_amnt': '41633.36', 'recipname': 'Jindal, Sanjeev'},
#  {'sum_amnt': '41592.77', 'recipname': 'Boyland, Tracy L'},
#  {'sum_amnt': '41574', 'recipname': 'Taylor, Al'},
#  {'sum_amnt': '41570.61', 'recipname': 'Pocchia, James M'},
#  {'sum_amnt': '41568', 'recipname': 'Miller, Harold C'},
#  {'sum_amnt': '41447.4', 'recipname': 'Watkins, Kimberly'},
#  {'sum_amnt': '41323.41', 'recipname': 'Morik, Helen K'},
#  {'sum_amnt': '41300.94', 'recipname': 'Ragusa, Michael'},
#  {'sum_amnt': '41004.74', 'recipname': 'Perez, Josue G'},
#  {'sum_amnt': '40895', 'recipname': 'Wills, Ruben'},
#  {'sum_amnt': '40822.06', 'recipname': 'Alamarie, Kaled A'},
#  {'sum_amnt': '40817', 'recipname': 'Holland, Marvin W'},
#  {'sum_amnt': '40728', 'recipname': 'Karako'},
#  {'sum_amnt': '40667.56', 'recipname': 'Caughman, Manuel'},
#  {'sum_amnt': '40566.00', 'recipname': 'Willabus, R. Dimple'},
#  {'sum_amnt': '40266.82', 'recipname': 'Downs, Thomas P'},
#  {'sum_amnt': '40175', 'recipname': 'Zuniga, Ceasar'},
#  {'sum_amnt': '40134.33', 'recipname': 'Ng, Stanley'},
#  {'sum_amnt': '40096', 'recipname': 'Bouchard'},
#  {'sum_amnt': '40028', 'recipname': 'Bilal'},
#  {'sum_amnt': '40012', 'recipname': 'Raffaele'},
#  {'sum_amnt': '39768.2', 'recipname': 'Ciafone, John'},
#  {'sum_amnt': '39564', 'recipname': 'Shepard'},
#  {'sum_amnt': '39437', 'recipname': 'Mujumder, Mohammed N'},
#  {'sum_amnt': '39376', 'recipname': 'Waid'},
#  {'sum_amnt': '39354.99', 'recipname': 'Seabrook, Larry B'},
#  {'sum_amnt': '39248.81', 'recipname': 'Serpe, Lynne'},
#  {'sum_amnt': '39211', 'recipname': 'Gonzalez-Jarrin'},
#  {'sum_amnt': '39061', 'recipname': 'Bloodsaw'},
#  {'sum_amnt': '38954.61', 'recipname': 'Ahmed, Moumita'},
#  {'sum_amnt': '38854', 'recipname': 'Giovinazzo'},
#  {'sum_amnt': '38779', 'recipname': 'Mirocznik, Mendy'},
#  {'sum_amnt': '38755', 'recipname': 'Somboun, April'},
#  {'sum_amnt': '38549', 'recipname': 'Jeffcoat, Marvin R'},
#  {'sum_amnt': '38529.01', 'recipname': 'Danzilo, Maria A'},
#  {'sum_amnt': '38308.83', 'recipname': 'Fox, Brian'},
#  {'sum_amnt': '38239', 'recipname': 'Heaphy'},
#  {'sum_amnt': '38227.66',
#   'recipname': 'Progressive Brooklyn Political Action Committee'},
#  {'sum_amnt': '38100', 'recipname': 'Downtown Independent Democrats'},
#  {'sum_amnt': '38047.24', 'recipname': 'Moore, Athena'},
#  {'sum_amnt': '38042.18', 'recipname': 'Batista, Raquel E'},
#  {'sum_amnt': '38041.5', 'recipname': 'Kalan, Felicia'},
#  {'sum_amnt': '38005', 'recipname': 'Kronfeld, Melissa Jane'},
#  {'sum_amnt': '37850', 'recipname': 'Toor, Harpreet S'},
#  {'sum_amnt': '37756', 'recipname': 'Gottlieb'},
#  {'sum_amnt': '37734', 'recipname': 'Foley, Mark'},
#  {'sum_amnt': '37625', 'recipname': 'Greenwood'},
#  {'sum_amnt': '37455.79', 'recipname': 'Cambranes, Victoria E'},
#  {'sum_amnt': '37424', 'recipname': 'Camarena, Rodrigo'},
#  {'sum_amnt': '37384.96', 'recipname': 'Osse, Chi'},
#  {'sum_amnt': '37216.31', 'recipname': 'Beltzer, Michael'},
#  {'sum_amnt': '36977.21', 'recipname': 'Taylor, Keith L'},
#  {'sum_amnt': '36967.54', 'recipname': 'Patzer, Steven'},
#  {'sum_amnt': '36960', 'recipname': 'Nunes, Lynn'},
#  {'sum_amnt': '36938', 'recipname': 'Hooks, Jr.'},
#  {'sum_amnt': '36876', 'recipname': 'Maragos, Angelo'},
#  {'sum_amnt': '36855.79', 'recipname': 'Mashariki, Jelani'},
#  {'sum_amnt': '36845.04', 'recipname': 'Grinage, David F'},
#  {'sum_amnt': '36749', 'recipname': 'Ariola'},
#  {'sum_amnt': '36561.42', 'recipname': 'Forman, Julia'},
#  {'sum_amnt': '36546', 'recipname': 'Spirgel'},
#  {'sum_amnt': '36484.26', 'recipname': 'Gowda, Rajiv S'},
#  {'sum_amnt': '36426', 'recipname': 'Rosero'},
#  {'sum_amnt': '36365', 'recipname': 'Toney'},
#  {'sum_amnt': '36115.5', 'recipname': 'Markh, Mariya'},
#  {'sum_amnt': '35860.99', 'recipname': 'Okporo, Edafe'},
#  {'sum_amnt': '35808.56', 'recipname': 'Walsh, Christopher'},
#  {'sum_amnt': '35762.98', 'recipname': 'Leandre, Jacques M'},
#  {'sum_amnt': '35745.93', 'recipname': 'Cohen, Albert'},
#  {'sum_amnt': '35718.71', 'recipname': 'Ordonez, Maria'},
#  {'sum_amnt': '35692', 'recipname': 'Hartman, Alec H'},
#  {'sum_amnt': '35643.66', 'recipname': 'Gagarin, Aleda F'},
#  {'sum_amnt': '35597.03', 'recipname': 'Kanu, Al-Hassan'},
#  {'sum_amnt': '35591.19', 'recipname': 'Vanel, Clyde'},
#  {'sum_amnt': '35550', 'recipname': 'Doukas'},
#  {'sum_amnt': '35500', 'recipname': 'Iannece'},
#  {'sum_amnt': '35367.39', 'recipname': 'Muhammed, Naaimat'},
#  {'sum_amnt': '35118', 'recipname': 'Encarnacion, Elsie R'},
#  {'sum_amnt': '35088', 'recipname': 'Adam-Ovide, Marie M'},
#  {'sum_amnt': '35033', 'recipname': 'Tapper'},
#  {'sum_amnt': '35000', 'recipname': 'Catholic Citizens Committee PAC'},
#  {'sum_amnt': '35000',
#   'recipname': 'Planned Parenthood of NYC Political Committee'},
#  {'sum_amnt': '34993', 'recipname': 'Schulman'},
#  {'sum_amnt': '34944.26', 'recipname': 'Scala, Mike'},
#  {'sum_amnt': '34941', 'recipname': 'Rivera, Haile M'},
#  {'sum_amnt': '34911', 'recipname': 'Torres, Thomas'},
#  {'sum_amnt': '34861', 'recipname': 'Shaw'},
#  {'sum_amnt': '34783', 'recipname': 'Bendet, Binyomin'},
#  {'sum_amnt': '34697', 'recipname': 'Sasson'},
#  {'sum_amnt': '34636.2', 'recipname': 'Nunez, Yorman R'},
#  {'sum_amnt': '34523.34', 'recipname': 'Richards, Kelvin'},
#  {'sum_amnt': '34473', 'recipname': 'Boudouvas'},
#  {'sum_amnt': '34427', 'recipname': 'Blake'},
#  {'sum_amnt': '34200', 'recipname': 'Yablon'},
#  {'sum_amnt': '34080', 'recipname': 'Fiala'},
#  {'sum_amnt': '34067.75', 'recipname': 'Schnall, Michael P'},
#  {'sum_amnt': '33970.5', 'recipname': 'Ryan, Allison L'},
#  {'sum_amnt': '33796.65', 'recipname': 'Hill, Rene'},
#  {'sum_amnt': '33655', 'recipname': 'Mateo, Heriberto'},
#  {'sum_amnt': '33525', 'recipname': 'Conigliaro, Michael S'},
#  {'sum_amnt': '33486', 'recipname': 'Hitlall, Romeo'},
#  {'sum_amnt': '33389.43', 'recipname': 'Velazquez, Manny C'},
#  {'sum_amnt': '33329.07', 'recipname': 'LaFargue, Aleta A'},
#  {'sum_amnt': '33295', 'recipname': 'Haq, Mamnunul M'},
#  {'sum_amnt': '33233', 'recipname': 'Levy'},
#  {'sum_amnt': '33221', 'recipname': 'Spitz'},
#  {'sum_amnt': '33215', 'recipname': 'Council, Billy K'},
#  {'sum_amnt': '32976', 'recipname': 'Junior'},
#  {'sum_amnt': '32940', 'recipname': 'Simon, Brian W'},
#  {'sum_amnt': '32804', 'recipname': 'Hammerman'},
#  {'sum_amnt': '32799', 'recipname': 'Frank'},
#  {'sum_amnt': '32737.67', 'recipname': 'Scala, Michael G'},
#  {'sum_amnt': '32337', 'recipname': 'Vargas, Cesar'},
#  {'sum_amnt': '32249.84', 'recipname': 'Pahaham, Cheryl A'},
#  {'sum_amnt': '32070', 'recipname': 'Kerpen, Dave'},
#  {'sum_amnt': '31958.52', 'recipname': 'Ferrara, Bernadette'},
#  {'sum_amnt': '31838', 'recipname': 'Behar, Steven Anthony'},
#  {'sum_amnt': '31685.0', 'recipname': 'Lora, Mino'},
#  {'sum_amnt': '31574.65', 'recipname': 'Nestler, Walter G'},
#  {'sum_amnt': '31570', 'recipname': 'Spencer'},
#  {'sum_amnt': '31500', 'recipname': 'Black Lives Matter PAC'},
#  {'sum_amnt': '31320', 'recipname': 'Wonica, George S'},
#  {'sum_amnt': '31299.58', 'recipname': 'Allen, William A'},
#  {'sum_amnt': '31259.13', 'recipname': 'Daniel, Kathleen'},
#  {'sum_amnt': '31256.98', 'recipname': 'Gardner, Sean P'},
#  {'sum_amnt': '31224.75', 'recipname': 'King, Erlene J'},
#  {'sum_amnt': '31196.45', 'recipname': 'Gomez, Ingrid P'},
#  {'sum_amnt': '31084', 'recipname': 'Perez'},
#  {'sum_amnt': '30806.6', 'recipname': 'Hayes, Sean C'},
#  {'sum_amnt': '30647.58', 'recipname': 'May, Daniella'},
#  {'sum_amnt': '30506', 'recipname': 'Miranda'},
#  {'sum_amnt': '30477', 'recipname': 'Kinard, Tulani'},
#  {'sum_amnt': '30443', 'recipname': 'Thomas, Koshy'},
#  {'sum_amnt': '30364.32', 'recipname': 'Fitzpatrick, Phelan-Dante'},
#  {'sum_amnt': '30337', 'recipname': 'Diallo, Ahmadou T'},
#  {'sum_amnt': '30326', 'recipname': 'Abdin, Misba'},
#  {'sum_amnt': '30259.02', 'recipname': 'Drabczyk, Olivia'},
#  {'sum_amnt': '30225', 'recipname': 'Williams, Nantasha'},
#  {'sum_amnt': '30192.93', 'recipname': 'Laymon, Jesse D'},
#  {'sum_amnt': '30130', 'recipname': 'Miranda, Anthony'},
#  {'sum_amnt': '30066', 'recipname': 'Perez Jr., Freddy'},
#  {'sum_amnt': '30036', 'recipname': 'Viest'},
#  {'sum_amnt': '29909.34', 'recipname': 'Zang, Donghui'},
#  {'sum_amnt': '29879.53', 'recipname': 'Rahman, Rubaiya'},
#  {'sum_amnt': '29830.32', 'recipname': 'Keehan-Smith, Denise M'},
#  {'sum_amnt': '29788.90', 'recipname': 'Bruno, Vito J'},
#  {'sum_amnt': '29706.71', 'recipname': 'Cabrera, Fernando L'},
#  {'sum_amnt': '29660', 'recipname': 'Moran'},
#  {'sum_amnt': '29521', 'recipname': 'Nijjar, Sukhjinder S'},
#  {'sum_amnt': '29516', 'recipname': 'Ashman, Dion M'},
#  {'sum_amnt': '29486', 'recipname': 'Miao, Chris Q'},
#  {'sum_amnt': '29480', 'recipname': 'Sansivieri'},
#  {'sum_amnt': '29444', 'recipname': 'Giraldo, Jose Eduardo'},
#  {'sum_amnt': '29396.46', 'recipname': 'Santos, Edward N'},
#  {'sum_amnt': '29393', 'recipname': 'Claxton, Marquez'},
#  {'sum_amnt': '29390', 'recipname': 'Sanchez, John'},
#  {'sum_amnt': '29277.83', 'recipname': 'Sosa, Christopher A'},
#  {'sum_amnt': '29171', 'recipname': 'Basch, Michael O'},
#  {'sum_amnt': '29147.00', 'recipname': 'King, Moreen A'},
#  {'sum_amnt': '29108.81', 'recipname': 'Biviano, Douglas J'},
#  {'sum_amnt': '29088.83', 'recipname': 'Florentino, Wilfredo'},
#  {'sum_amnt': '29071', 'recipname': 'Meadows, Alexander R'},
#  {'sum_amnt': '29010', 'recipname': 'Swinton, Victor'},
#  {'sum_amnt': '28963', 'recipname': 'Hornak, Robert A'},
#  {'sum_amnt': '28911', 'recipname': 'De La Fuente, Roque R'},
#  {'sum_amnt': '28874', 'recipname': 'Figueroa'},
#  {'sum_amnt': '28822', 'recipname': 'KC, Nabaraj'},
#  {'sum_amnt': '28690', 'recipname': 'Arroyo'},
#  {'sum_amnt': '28686.43', 'recipname': 'Gotlieb, Brian L'},
#  {'sum_amnt': '28686.24', 'recipname': 'Bauza, Joel M'},
#  {'sum_amnt': '28621.25', 'recipname': 'Reilly, Gary G'},
#  {'sum_amnt': '28502', 'recipname': 'Mateo'},
#  {'sum_amnt': '28471.84', 'recipname': 'Gray, Tyson-Lord J'},
#  {'sum_amnt': '28348.95', 'recipname': 'Baer, Kenneth J'},
#  {'sum_amnt': '28298.48', 'recipname': 'Chow, Bernard'},
#  {'sum_amnt': '28171.32', 'recipname': 'Melo, Liliana C'},
#  {'sum_amnt': '28138', 'recipname': 'Wasserman'},
#  {'sum_amnt': '28058', 'recipname': 'Del Villar'},
#  {'sum_amnt': '27936', 'recipname': 'Reiss'},
#  {'sum_amnt': '27865', 'recipname': 'Weiner, Anthony'},
#  {'sum_amnt': '27855', 'recipname': 'Johnson, Monique S'},
#  {'sum_amnt': '27810', 'recipname': 'Brook Krasny, Alec'},
#  {'sum_amnt': '27542.44', 'recipname': 'Castro, Maria'},
#  {'sum_amnt': '27436.54', 'recipname': 'Credico, Randy'},
#  {'sum_amnt': '27424', 'recipname': 'Rosen, Seth M'},
#  {'sum_amnt': '27398.49', 'recipname': 'Wong, Edwin'},
#  {'sum_amnt': '27389.17', 'recipname': 'Henry, Sean K'},
#  {'sum_amnt': '27257.96', 'recipname': 'Pabon, Julio'},
#  {'sum_amnt': '27028', 'recipname': 'Gleason'},
#  {'sum_amnt': '26940', 'recipname': 'Allen'},
#  {'sum_amnt': '26695', 'recipname': 'Ruiz'},
#  {'sum_amnt': '26609', 'recipname': 'Puello'},
#  {'sum_amnt': '26607', 'recipname': 'Rias, Alexander N'},
#  {'sum_amnt': '26575', 'recipname': 'Grey, Selina'},
#  {'sum_amnt': '26516.97', 'recipname': 'De Los Santos, Manny'},
#  {'sum_amnt': '26398', 'recipname': 'Yin, Dao'},
#  {'sum_amnt': '26017', 'recipname': 'Hochhauser'},
#  {'sum_amnt': '25936.86', 'recipname': 'Mohan, Radhakrishna'},
#  {'sum_amnt': '25930.79', 'recipname': 'Berkley, Carlton'},
#  {'sum_amnt': '25766.03', 'recipname': 'Kavovit, Barbara'},
#  {'sum_amnt': '25706', 'recipname': 'Galarza'},
#  {'sum_amnt': '25660', 'recipname': 'Morris, Blake'},
#  {'sum_amnt': '25658', 'recipname': 'Cooke, Thomas E'},
#  {'sum_amnt': '25474.46', 'recipname': 'Polanco, Juan Carlos'},
#  {'sum_amnt': '25361.25', 'recipname': 'Tillard, Conrad'},
#  {'sum_amnt': '25239.46', 'recipname': 'Pacheco, Ricardo J'},
#  {'sum_amnt': '25141', 'recipname': 'Hankerson, Tyrell D'},
#  {'sum_amnt': '25115', 'recipname': 'Wein'},
#  {'sum_amnt': '25095', 'recipname': 'Lewis, Prince D'},
#  {'sum_amnt': '25047', 'recipname': 'Flores, Raja M'},
#  {'sum_amnt': '25038', 'recipname': 'Poisson'},
#  {'sum_amnt': '25036.21', 'recipname': 'Lee, He G'},
#  {'sum_amnt': '24945', 'recipname': 'Mahadeo'},
#  {'sum_amnt': '24867', 'recipname': 'Nath'},
#  {'sum_amnt': '24821.21', 'recipname': 'Cunningham, Brian A'},
#  {'sum_amnt': '24808', 'recipname': 'Stavitsky'},
#  {'sum_amnt': '24789', 'recipname': 'Brook Krasny'},
#  {'sum_amnt': '24760', 'recipname': 'Evans'},
#  {'sum_amnt': '24711', 'recipname': 'Cammarata'},
#  {'sum_amnt': '24658.59', 'recipname': 'Alvarez, Albert'},
#  {'sum_amnt': '24652', 'recipname': 'Alamo-Estrada'},
#  {'sum_amnt': '24551', 'recipname': 'Doty'},
#  {'sum_amnt': '24492', 'recipname': 'Ye, Ling'}]

# %% [markdown]
# ### Break download into managable chunks
#
# Sometimes you do want all the data, but it would be too big for one download.
#
# By default, all queries have a limit of 1000 rows, but you can manually set it
# higher or lower. If you want to loop through results, just use `offset`

# %%
results = client.get(
    socrata_dataset_identifier,
    limit=6,
    select="name, amnt",
    where="name is not null",
)
results
# Out:
# [{'name': "THE SPACE AN ARTISTS' COLLEC", 'amnt': '50'},
#  {'name': '. HASSAD, ABDOOL K', 'amnt': '100'},
#  {'name': '?, SAUL', 'amnt': '25'},
#  {'name': '1-10 INDUSTRY ASSOCIATES LLC', 'amnt': '4500'},
#  {'name': '100  CHURCH LLC', 'amnt': '2000'},
#  {'name': '100 MOSHOLU PARKWAY ASSC. LLC', 'amnt': '500'}]

# %% [markdown]
# To retrieve _all_ records, you'd use [`get_all()`](../README.md#get_alldataset_identifier-content_typejson-kwargs).

# %% [markdown]
# ### Query strings
#
# All of the queries above were made with method parameters,
# but you could also pass all the parameters at once in a
# SQL-like format

# %%
query = """
select
    name,
    amnt
where
    amnt > 1000
    and amnt < 2000
limit
    5
"""

results = client.get(socrata_dataset_identifier, query=query)
results
# Out:
# [{'name': 'Freudenheim, Ellen', 'amnt': '1000.18'},
#  {'name': 'Kurland, Yetta G', 'amnt': '1000.31'},
#  {'name': 'Chain, Heidi H', 'amnt': '1000.94'},
#  {'name': 'SONI, KRISHNAKUMAR L', 'amnt': '1001'},
#  {'name': 'SUGIMOTO, YUJI', 'amnt': '1001'}]

# %% [markdown]
# ### Free text search
#
# My brother just got a dog named Slider, so we were curious about how many other New York City dogs had that name.
#
# Searches with `q` match anywhere in the row, which allows you to quickly search through data with several free text columns of interest.

# %%
nyc_dogs_domain = "data.cityofnewyork.us"
nyc_dogs_dataset_identifier = "nu7n-tubp"

nyc_dogs_client = Sodapy(nyc_dogs_domain, socrata_token)
results = nyc_dogs_client.get(
    nyc_dogs_dataset_identifier, q="Slider", select="animalname, breedname"
)
results
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# [{'animalname': 'SLIDER', 'breedname': 'American Pit Bull Terrier/Pit Bull'},
#  {'animalname': 'SLIDER', 'breedname': 'Cavalier King Charles Spaniel'},
#  {'animalname': 'SLIDER', 'breedname': 'Shih Tzu'},
#  {'animalname': 'SLIDER', 'breedname': 'Wheaton Terrier'},
#  {'animalname': 'SLIDER', 'breedname': 'Cavalier King Charles Spaniel'},
#  {'animalname': 'SLIDER', 'breedname': 'Shih Tzu'},
#  {'animalname': 'SLIDER', 'breedname': 'Golden Retriever'},
#  {'animalname': 'SLIDER', 'breedname': 'Shih Tzu'},
#  {'animalname': 'SLIDER', 'breedname': 'Unknown'},
#  {'animalname': 'SLIDER', 'breedname': 'Shih Tzu'},
#  {'animalname': 'SLIDER', 'breedname': 'Shih Tzu'},
#  {'animalname': 'SLIDER', 'breedname': 'Dachshund, Long Haired Miniature'},
#  {'animalname': 'SLIDER', 'breedname': 'Dachshund, Long Haired Miniature'},
#  {'animalname': 'SLIDER', 'breedname': 'Shih Tzu'}]

# %% [markdown]
# # Going Further
#
# There's plenty more to do! Check out [Queries using SODA](https://dev.socrata.com/docs/queries/) for additional functionality
